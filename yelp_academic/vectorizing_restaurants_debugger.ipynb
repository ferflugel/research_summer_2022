# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from yelp_functions import get_processed_inputs

# read file with reviews data for restaurants
reviews = pd.read_csv('processed_data/reviews_restaurants.csv')

# create a BoW vectorizer using a random sample of 10% of the reviews
vectorizer_inputs = reviews.sample(frac=0.1, random_state=0)[['text']]
vectorizer_inputs = get_processed_inputs(vectorizer_inputs)
vectorizer = CountVectorizer(max_features=4096, ngram_range=(1,2))
vectorizer_inputs = vectorizer.fit_transform(vectorizer_inputs)

# %%
# zip the id's and prices together
restaurants_zip = list(zip(list(reviews.groupby('business_id').mean().index),
                           list(reviews.groupby('business_id').mean()['price_range'])))

# check results of sampled zip
restaurants_zip
# Out:
# [('--0iUa4sNDFiZFrAdIWhZQ', 1),
#  ('--7PUidqRWpRSpXebiyxTg', 2),
#  ('--8IbOsAAxjKRoYsBFL-PA', 2),
#  ('--ZVrH2X2QXBFdCilbirsw', 1),
#  ('--epgcb7xHGuJ-4PUeSLAw', 1),
#  ('--lqIzK-ZVTtgwiQM63XgQ', 1),
#  ('--onnLZrsCazmcy2P_7fcw', 2),
#  ('--qLiYw2ErSmvVwumb2kdw', 3),
#  ('-09Oc2D14vRnmirPh0vlXw', 2),
#  ('-0G_6-KFGpCpxTUlVXCMYQ', 2),
#  ('-0M0b-XhtFagyLmsBtOe8w', 2),
#  ('-0PN_KFPtbnLQZEeb23XiA', 2),
#  ('-0TffRSXXIlBYVbb5AwfTg', 2),
#  ('-0__F9fnKt8uioCKztF5Ww', 2),
#  ('-0dKgi_Hpcis921nOpM85Q', 2),
#  ('-0eUa8TsXFFy0FCxHYmrjg', 1),
#  ('-0epFLgYq2C1Jo_W4FOBKw', 1),
#  ('-0gWtMKg8_iV6vC5wRFDiA', 1),
#  ('-0i2KNr7WrCsDF5m0IViJg', 2),
#  ('-0iIxySkp97WNlwK66OGWg', 1),
#  ('-0jK77zdE3-plqXuwXtilQ', 2),
#  ('-0jzoPt3UeXn6FUXVQvyPg', 2),
#  ('-0m4IwD1FIOqkA8dh4mVfQ', 1),
#  ('-1B9pP_CrRBJYPICE5WbRA', 2),
#  ('-1MhPXk1FglglUAmuPLIGg', 1),
#  ('-1PG6k_iezwJmRZLB7f6og', 2),
#  ('-1PvWminK3Er7fqpTjk19A', 2),
#  ('-1WM2044r3jVZC6oQ2QeVA', 1),
#  ('-1XSzguS6XLN-V6MVZMg2A', 3),
#  ('-1b2kNOowsPrPpBOK4lNkQ', 2),
#  ('-1iLbEf1NwY-OJp5Hg-3Sg', 1),
#  ('-1owBLC2h6DF5n_j77oq3g', 1),
#  ('-1oygVebK81K8JEPI6H6Lw', 1),
#  ('-1q9ktAQXpgFSNrst7tzag', 1),
#  ('-2-ih3mE8KPyeKVIzpBfPQ', 2),
#  ('-2Axhv9AZ_n7qjQefECpVw', 1),
#  ('-2BDt9OdGiBONysWCdKgNg', 1),
#  ('-2CPhK6ik9ZBgFX_F-dkxQ', 1),
#  ('-2HaAaQODTx0sr2srL553Q', 3),
#  ('-2KK9cqa26KZ1xrfOm9A7w', 2),
#  ('-2Plk-e7jgKYLOPE6hzoQA', 1),
#  ('-2VYztMXVorktljCdQNPmQ', 2),
#  ('-2YZIUArmrIMVVBi8CT47w', 2),
#  ('-2dvQxx3cYXd5XmFdDDsDA', 1),
#  ('-2gDGXUYPigcPbMIDg2eTg', 1),
#  ('-2gmbMDzKgYZ_8DOnJtPyw', 1),
#  ('-2ke_JDOpgTZWqirMFjZcw', 1),
#  ('-2oyyfOSHs1UElr3Dc1aKQ', 2),
#  ('-2vEnMoexef2-rWy-FMWvw', 2),
#  ('-3-6BB10tIWNKGEF0Es2BA', 2),
#  ('-32hOCwsuKd04WO-HQyYFg', 1),
#  ('-361Hc0tlxSYdrH_C3OgzA', 2),
#  ('-3725FZiIIYdwQtM4MKEIA', 1),
#  ('-3AooxIkg38UyUdlz5oXdw', 2),
#  ('-3ArWZfDjfab8qVHf3WVtg', 1),
#  ('-3GD07waps96fB_okEwFqw', 2),
#  ('-3IOd5YntpkbK6RwT3HYtA', 1),
#  ('-3Mc8R5c23FxrxlJn3ivww', 1),
#  ('-3Xl8nSBSjaPpftsSNyrgg', 1),
#  ('-3m_nXlyvdKAVNNmVirpGQ', 2),
#  ('-3xX_IfttKjPJ792BOBJ-Q', 1),
#  ('-3yc7i3bvTHv1Zig2rXrSg', 3),
#  ('-40qQXB8JsneSiDqXMjoeg', 2),
#  ('-46lOITML86TZkk2fErq6A', 2),
#  ('-49SvmoGFrpZj5jmT1n4Sg', 1),
#  ('-49YlJ2GGzgmQ71FX9gGyg', 1),
#  ('-4E0hSCldRJZLI-1cT38Sw', 2),
#  ('-4HTX6yWNuRJusCTezaUnQ', 1),
#  ('-4IoP43clvfZPjRlXu2LLA', 2),
#  ('-4J6iW94f7qhnwmp4Z9bdg', 1),
#  ('-4jxTEaNONDDsC0Xzzp1UQ', 1),
#  ('-4mDMBfT6N0d-VIUTKVaLg', 1),
#  ('-4qgeqxb2hKe3dUUH__j8Q', 2),
#  ('-4wykApCGL78JzWYICOQzw', 1),
#  ('-4x3pVUUsfWmKEilWKsOZQ', 2),
#  ('-5DcSecinHF2snC4eLv8WA', 2),
#  ('-5Rah4ZvWsDu4oilUZxhtw', 2),
#  ('-5UQGwUZWUhPi5pJlcwEYA', 2),
#  ('-5ivHc7R7F_fHxTtxGvlgA', 2),
#  ('-5jrKrVFNFBuT6OKHme7WQ', 1),
#  ('-5psHqEISccHDdHaWF2-6Q', 1),
#  ('-63ytt5vkWof-M9NDGTkng', 1),
#  ('-66jJ8Hl0vLV5PMxySNbXA', 1),
#  ('-6JdVK-DHB4_43PEksbg1A', 2),
#  ('-6L7ckMsebhvS_nk4wjhIA', 1),
#  ('-6OjnX3ZdDOhHxWR60wysg', 2),
#  ('-6TttC-1-rf5gC0QHWrs_w', 1),
#  ('-6eomXaFuOSKPsUbk2A3xQ', 2),
#  ('-6jVwUuXC1-dyr2YRCEU6Q', 2),
#  ('-6kNhGurAbdNQanqbAaoMg', 2),
#  ('-6nQZ-QCkAyNHdtaxOxDpQ', 1),
#  ('-6nqH2tdNHQdqb8LvILlBw', 2),
#  ('-6osFx4NgFRHJ5NXqpHV6g', 1),
#  ('-788YqeAedOZseDJOo7kfQ', 2),
#  ('-78Va3llKcPbL6SW4is8lw', 2),
#  ('-7AGjO0qnOld_GZK9dNNkQ', 2),
#  ('-7CqBmK0zxwyjEqa3LBVSw', 1),
#  ('-7DvdvlUs5fHfSITPbvjgg', 1),
#  ('-7GDqSUaXrpC8Ql7nDBxWA', 4),
#  ('-7KAng29RoHr87mvOFbK9w', 2),
#  ('-7KnD-G4ZYi7-Xs4ZJAYWQ', 2),
#  ('-7Rx5jVeQmlVoAU_oXrzew', 1),
#  ('-7UDKbg_8TL4LVuYR6Ooyw', 1),
#  ('-7ZTpN4KmfWotnu4rVV-FA', 1),
#  ('-7cNgs6N105MDlLjOudObg', 2),
#  ('-7iiapq3BMer7eW-NRXd2w', 1),
#  ('-7wXZWnKe26iwJY_5z_AAw', 3),
#  ('-81BXpO5Fuk-RqCabS7LMw', 2),
#  ('-8B29WNRCyg4jViK4ChKlQ', 1),
#  ('-8NGFqFrlOmWawr827tZNg', 2),
#  ('-8VpP01AKfnt4wpT-8vgnQ', 1),
#  ('-8gGD85_jZvapnmb3EvU3w', 2),
#  ('-8iATYRnN46Km0_-ldx6cg', 2),
#  ('-8jIGHKz1-Tnv2X85kxbvQ', 1),
#  ('-8luB5pJ7d9UOoiF7wikkw', 1),
#  ('-8oD6dtRRUpkIFSkJ46UqA', 2),
#  ('-8oIIpYJAXWg-G3glapMmQ', 2),
#  ('-8uatt4iWxUproNMOd1srw', 1),
#  ('-8xqG21DUzav7yIp5lS6jw', 2),
#  ('-97632CUoOkJ8x4AlkPJxQ', 1),
#  ('-99CauTgdResVER5NvRTfw', 1),
#  ('-9CvbWc-vPYsoioAgZii4Q', 2),
#  ('-9Kxik9BRNkft5rPcVvSsw', 2),
#  ('-9lL4yFBX_7XVqUr8cwytg', 1),
#  ('-9r8nAzWyRSLxBWt8uQOdA', 1),
#  ('-9rRsa_9GTkSYkPdKa7T8A', 2),
#  ('-9w_8PChjtA42yGN4yoDRw', 1),
#  ('-9yzQQ0d_rcOD2CzdTNO_Q', 1),
#  ('-9zDI4h2dE3hFOpGFHB10Q', 1),
#  ('-A-5spZpPMjujSnG-Oag7w', 1),
#  ('-A10ZTqT4X49cneKlxXTcw', 2),
#  ('-A2OLubXDsMRPNN7LqohPA', 1),
#  ('-A7I5CQcKkxH_CUyG3PVQA', 1),
#  ('-ALqLSTzkGDMscHdxA1NgA', 1),
#  ('-AQyGGLrejN1uLaJM-a6mQ', 1),
#  ('-ATiAtTikuGuqvaW2O6tNA', 2),
#  ('-AWclhh1_2VnqPylPgBU3g', 2),
#  ('-AanHawaDlzWHQjrqRRWig', 1),
#  ('-AbzJTLQdbdQrhRzQLgsKA', 2),
#  ('-AgYybTLhispcYcoIV7E9A', 2),
#  ('-Ah-gbZpa-IiQVIrhKRhhA', 2),
#  ('-AhpS4MUSdYWg8SwZpV6eA', 1),
#  ('-AvUCI3vOj4gww3s21WsDg', 3),
#  ('-AxGGm4yvhedkmN1glW1Xw', 2),
#  ('-B6XL-ZWsVHlAQyYcd3eEg', 2),
#  ('-B6fyJ8PoAMr_mH5VGaPjA', 1),
#  ('-B7E8MFb47FoGcp25lXgxw', 1),
#  ('-BFrwPGCH-22kRPvFrFk4Q', 2),
#  ('-BLKZfw-FX7602K59OpBgg', 1),
#  ('-BLVl824WRLFIm_uiHmkbA', 1),
#  ('-BPvsLwU9XqGRD275rEpsw', 2),
#  ('-BWNwPx6dtSRXXqFnCgO5Q', 1),
#  ('-B_2jHrwV2nWNqdoWtBC8A', 2),
#  ('-Bhoyo7LL97tgt9Hze0Saw', 1),
#  ('-Bsw0AjWemVa8D_7g7-9Kg', 2),
#  ('-C0DXAsxofWlGIcY1y-edQ', 2),
#  ('-C3uMHgUbV0LxV0rJ7z6EQ', 1),
#  ('-CJaGFoVnofRPKwl4NJaLg', 2),
#  ('-CLHHZzNmv1DYqyNQmlNtA', 1),
#  ('-CLLdRWg2JJ6QUVj33HYNg', 2),
#  ('-CRjqZ4GxZ6lIa_qMj7-yw', 1),
#  ('-C_5RtXY4iIoztzIYVqMSQ', 1),
#  ('-CbBGlrmddJsaruk6LdI6A', 2),
#  ('-CiuESq1Pb0_x2TGi74oyg', 1),
#  ('-CvjeIt8CMUMBRnikhHCDg', 1),
#  ('-DGsnMlRrR_tv8avrpQLQw', 2),
#  ('-DHwIpXvOsJFqYuo585eOg', 2),
#  ('-DJmkn9HGCpCTF9G1ozklw', 2),
#  ('-D_InZvA0lq497RtoNxofw', 1),
#  ('-D_L4GHXJQvy2wv0RkrupA', 1),
#  ('-DcAq3aOYlMTM0vzOIAMMw', 2),
#  ('-DcRlgZdSCM0nQu4w4UI7g', 1),
#  ('-DffuTBxcKochiDa4QKPwQ', 1),
#  ('-Dg2pJigtydnPUUW5XBamQ', 1),
#  ('-DlF6neBa1HKx7aFi3ZxOg', 1),
#  ('-DmrgCX-mgijdP_dY-6Vuw', 1),
#  ('-Dr6MZW6ZVP7X6ai30Qrlw', 1),
#  ('-DsC3cvCBEy_FNJ7U-i9zg', 2),
#  ('-E0TZWKHz2y1Z_ZsYqWpag', 1),
#  ('-E2h36etKkz5AbIMaoOYWQ', 2),
#  ('-EAUflIYeDktN8f7wHpHOg', 2),
#  ('-EGUHD80Yj0_bsBImJCITg', 1),
#  ('-EHrU_DwtX2Jv4NbAMppTA', 2),
#  ('-EUDiY3WrnAvDW9QDCNGMw', 1),
#  ('-EZ84vTWjXnQCeE1-qVuSA', 1),
#  ('-EagpVR7BtB0fLun70vg_g', 2),
#  ('-EiVVg6mJMzzr13_j8PNog', 1),
#  ('-ExvxN1QHx4efMLm6PxJ4A', 2),
#  ('-FIYPnxsg3kuHXx46zY18w', 2),
#  ('-FKVxYp6GWcQjG8t2DC7vw', 2),
#  ('-FM4CxOg4XXmX_Ebky_SiQ', 2),
#  ('-FMI0_EhMjwXaAgHVGuG2Q', 3),
#  ('-FPHImCrh555pkxNetpreA', 2),
#  ('-FRHYI6doGCjIsXiKHkUqw', 1),
#  ('-FXxCFnPPya9o5_8wAVSGQ', 2),
#  ('-FYgaeBm9xNhF4_m8bCC0A', 2),
#  ('-FasKNAqishyfjAarVgJtw', 2),
#  ('-Fka99c-tJ-epWYNIobqyQ', 2),
#  ('-FplUfMbM6YNKtwppNddxQ', 2),
#  ('-FrJ1Y-s31IQkqnbajBHaA', 2),
#  ('-G2E_TAWXZehcQBirPGwZw', 2),
#  ('-GLapzja21a5YL98C7Zxxg', 2),
#  ('-GfCU3f2UqupobhRd0d5og', 1),
#  ('-GqJOzN8AxFnkqSuvzmPtQ', 2),
#  ('-GvA6iekqOACGodgLYiMKA', 2),
#  ('-Gy7yBHvRZK64jNxYYJWWA', 1),
#  ('-H-fZonTLitwHFY_PLAIjA', 2),
#  ('-H5v2-mADBj8_n2yeACjLA', 2),
#  ('-H6a4mIT5GbQiiWZz2luOw', 1),
#  ('-H6s1c2NRic5UKxXqi4FdQ', 1),
#  ('-H8ryT3wGAoHMa9NeZ4tNQ', 3),
#  ('-HL8513QTgQ50vWjtg2Dyg', 2),
#  ('-HMqisHgmwr4k8zwT3tp5Q', 2),
#  ('-HPQAylabtzueY4Hxm2NSA', 2),
#  ('-HPx2qKK5EDSltrtd1s2rg', 2),
#  ('-HSWvV_IvXtMFzApwjF6YQ', 2),
#  ('-HTra3AbYlsjx1VIlsIJbw', 2),
#  ('-HWc5-NQLKBIIlBcDMfKCw', 1),
#  ('-HbvKXJ7yMsOefB6SHd3KA', 1),
#  ('-HcABf2Y81fglisWWXPYdQ', 2),
#  ('-HewctWQ0P3HqKCr76bU-g', 1),
#  ('-HjH9XFJ8lS5Mq-uTsR4OQ', 2),
#  ('-HoCrhW2f7610NWGDemnjw', 2),
#  ('-HxLFWKVgXSU8JlR21PBkg', 2),
#  ('-Hy4ZQeR6wDeVRyT7cWBJQ', 2),
#  ('-I6kYJze5to1AISg9i30-w', 2),
#  ('-I7M6l0h46VdiN09Y1NUZw', 2),
#  ('-I8rPwW2mH-pxMeyk22f7g', 2),
#  ('-IOWVdmqsfd02_G-nJACdQ', 2),
#  ('-IQsXtexaUmIfSBkhBZrKQ', 3),
#  ('-I_MttjEEbECi1Zjs12hJA', 2),
#  ('-IabZS0yj6jdb4f4FnKu6w', 1),
#  ('-If0ps0QhOLCYVWQWs9RYg', 1),
#  ('-Isbi5itk9FsJNwlZoFrjQ', 1),
#  ('-IvBAqkaQcDt-fj-KhOFpQ', 2),
#  ('-Ivxg9G5OM06u3cVVfYZrw', 1),
#  ('-Iwzp-1JyrQFUOLEmaDavA', 2),
#  ('-J0tPzkwPnyulSBE_s863Q', 2),
#  ('-J5blpzmnpQZpmb85pWAZw', 1),
#  ('-JAwNIEJoDXmdE_8sS_BJQ', 2),
#  ('-JGkEsPcn-hoFspX1reyoA', 2),
#  ('-JPtuF_UEDno3F7ecmPTQA', 1),
#  ('-JQ6tBgz-YUD5HjJXIRKYg', 3),
#  ('-JStjL-8mRZq4ov4uI1FaQ', 2),
#  ('-JcSG0yNk06hpNWagOKj9g', 1),
#  ('-JkiE867GwCUuXFETjba2w', 2),
#  ('-JpnQBGy8daXKvMvtjto2w', 1),
#  ('-Jx4CvmKL84niPDlnuMNsw', 1),
#  ('-K0LoSCfh8i5U_y53Krepg', 3),
#  ('-K0zTgGyxo-AeSkcV0IVaA', 2),
#  ('-K2Gmr6UXxsBdH7Ep6oDBg', 2),
#  ('-KF7ehdZ-fDv8nK40IEwjw', 1),
#  ('-KJuzqptSAbZtTRgcyFduQ', 2),
#  ('-KNgMklrxgRX2-T6xXeTZA', 2),
#  ('-KQsS-zouGNa6qczrzO0Ew', 2),
#  ('-KWel73upKHxstRCr9JGLw', 2),
#  ('-K_FDDqmOt6hJLTOPgpnlA', 1),
#  ('-KdeX92-JV2K8GWbAxVj2w', 2),
#  ('-KgOEg5ptVVJBSvhHXXkBw', 2),
#  ('-KhT2eqHZUj-Sqz3xkt-kw', 1),
#  ('-Khy_h5lLuhzCts3c318_g', 1),
#  ('-KncfNxXHo2DA46fR39K5w', 1),
#  ('-Kro8CtHkk9Ge9MMDK8t7g', 1),
#  ('-KugJyLmuTECAE121jsCkg', 1),
#  ('-KyQ_Bu21JNphNtxz-Jj-g', 2),
#  ('-L3E_h6OUJ7kRW2EDMFESQ', 2),
#  ('-L4ZVlzmrVKCs6F7ucgikA', 2),
#  ('-LA43tgCUKqAX4ws4cIz6g', 1),
#  ('-LI-pZMk96s4VqGwIU1dNg', 1),
#  ('-LNcgHYLXcO7greCh81kpg', 2),
#  ('-Lfib0jjHweCly1-FLM_og', 2),
#  ('-LoVysdztSNMiUeHCw8Ldg', 1),
#  ('-LpG-lx52Mjp7jyJ8YZHZQ', 1),
#  ('-Lwq2vdrQolANLzEbYMPpQ', 1),
#  ('-M7wzxpUsdSkQd9PDGsJWA', 1),
#  ('-M9uwwh6jHbzjHOm2N5fHg', 2),
#  ('-MRgqfCoHgUNdvszLRgDcw', 2),
#  ('-MXWHvyw73IDWzIrpGqkpA', 2),
#  ('-Mhf-oRV5HcckZ2wjR9ZaA', 2),
#  ('-Mig1TcxvFWREy-pfx7rZQ', 2),
#  ('-MkngKKkTIVfnUbq2S1ucQ', 2),
#  ('-Mo06YDZmfDbPHfZ8auGPA', 2),
#  ('-MpXo24qYu4DazQXDrs2oA', 2),
#  ('-MqloFCBP89OWko_A6i1_A', 1),
#  ('-MwKwvY0gG3GyR5ymxsLNQ', 1),
#  ('-N9ysCcO-ekOMlwidbn0FA', 1),
#  ('-NG3pA9LEXCxt0Fjd_aYYA', 1),
#  ('-NH2sUTm3EJsbBEHdA4BSg', 1),
#  ('-NXRuUsazxXZZ_OHwmtYtw', 2),
#  ('-NZAlu3TfzLLR_VUe6U3kQ', 1),
#  ('-NcOafeJBugr-Al5L1vMWA', 2),
#  ('-Nf2K8OmZ3OaApWamQHrbw', 1),
#  ('-O-j-LQ4yNAjQRRT37Xjow', 1),
#  ('-OIUunijjcq_ZzyyQhPPFQ', 2),
#  ('-OPBG2cRwGxa2dlchfVdjQ', 1),
#  ('-OWsJkkKmcMA8ecGLSUg7w', 2),
#  ('-OX0MJDPRHV0RCRvwYnvBQ', 2),
#  ('-O_IkEBfG-63san1Pwg2Tg', 1),
#  ('-O_fh3A0IdvR_sg--mmoPQ', 1),
#  ('-Oc3gtgcrsApbBPCUoA4rg', 1),
#  ('-OdMe4WXmGGIPEoSTM8C9Q', 1),
#  ('-Om8XgP9GZ4UUFbgTRI4YQ', 2),
#  ('-Or44IdY51Ukd618kikmtA', 1),
#  ('-P-pHBN0NA3cE3jjvA2jbg', 2),
#  ('-P0cVKNzgqsqBsKkwngvpA', 1),
#  ('-P6TzxVyvvsLJs4O3E6DcA', 2),
#  ('-P7CxFXqAyZ7_ep4r4W-Zg', 2),
#  ('-PFZiUpnk6DKtz2PpeFbHQ', 1),
#  ('-PMXnNJ1D67NkAupRHNkpQ', 1),
#  ('-PQlbIJ0ShH_aRVgzvBWgw', 2),
#  ('-PTWFicakClBDK-zyQ5hjA', 2),
#  ('-Pd_tj2g-SGmOeVy718PPA', 1),
#  ('-PkchovDBosOtZx4XLatVw', 2),
#  ('-Pq_I1Dqc7W0xf3A6SJTpQ', 2),
#  ('-PqeUUIN8Qgqhv5KMiRfHA', 1),
#  ('-PvUiRhg9Nuy0l_dJX-IfA', 1),
#  ('-Q32uZ1kdfhd9-KgTATx-A', 1),
#  ('-Q9l-6rQpExmerxk3BMahA', 2),
#  ('-QP2hZmYtQh-UFUA4llVVg', 2),
#  ('-QbbFXdiWQb2vKaDIky4Pw', 1),
#  ('-QiXa-Cuoug5TSTImGCYGA', 1),
#  ('-QmdKVHCKxbyZJ5JgKFQNw', 2),
#  ('-QpRF-N2_Pga52VgNMipNA', 2),
#  ('-QvV4HrMXMA8fJxCWJOFBA', 1),
#  ('-R9t30RvsG-Rtiq63yuEmg', 2),
#  ('-RCy49doG-2XARGzr9Do5Q', 2),
#  ('-RIsIJJw3cx98ba8BiWI6Q', 2),
#  ('-RJfiKv_UsYol83dkfqpHQ', 2),
#  ('-RLJlk68dmL--ff0lsP0JQ', 1),
#  ('-RQonzDENNng8tXzukUUww', 1),
#  ('-RS_7SU42foCTItx4f3C6A', 1),
#  ('-R_Iq2rBvO9oTcZN5Ex6XQ', 1),
#  ('-RckAAIJ-_KH0AzqrekYuw', 1),
#  ('-RkGrQUxlwgaR5By4p2tAQ', 1),
#  ('-Rmxzme0KxjvRG45p4gqlA', 1),
#  ('-Rn6U-ySYo_Lx9vCgDSooA', 1),
#  ('-SEIjzWcRg49Eloagyqywg', 2),
#  ('-SEU6rdhRihUxmPYQIPoeA', 2),
#  ('-SFSt3FkjGfavnyMpHsZPA', 2),
#  ('-SGvS9V0Yc5Ler2HrgtYJw', 2),
#  ('-SHVMQDi7A_095sDzARNnw', 2),
#  ('-SQ7N9P7LjZ0Th0GmXNDNw', 1),
#  ('-SQv9Kit89XgEik-Rd_5yg', 1),
#  ('-SS3ep20HKhuOhzDkkt9aA', 2),
#  ('-SZ-p4o6gJPOJ--HA3NKcw', 2),
#  ('-SZsZMvsCvgeEOKCMBLmvQ', 2),
#  ('-S_B3PbeFbT0dPpqd0zQEw', 3),
#  ('-SguV7aNlTXbsdkyJI4baw', 2),
#  ('-ShzgoeH2nvGG_TlNfMz2w', 2),
#  ('-Sp511jqTCpn3d6NwVz69g', 1),
#  ('-T1sYi2cqB2oW4GeUXmIBQ', 2),
#  ('-T5SfUI_QqgBrkq4D8Jn7w', 2),
#  ('-T7DOQMC_XmMn80ugBL_6A', 2),
#  ('-TArOdux8Z4oH-jIM1FJuQ', 2),
#  ('-THauPUGjEYdwUAne95wWg', 2),
#  ('-TOH0kmSwfAbPckNx0BBgw', 1),
#  ('-TRXiliBZ2O2_BKyKQ32HA', 1),
#  ('-TTt6Cxzo7eS7hnI2P5Urw', 1),
#  ('-T_lkOvaK39R-Ufg6VUyxg', 2),
#  ('-TczrbbjQKfoNGCeNXcurg', 1),
#  ('-TjT3y-Glfnbt6LbKETAYg', 2),
#  ('-Tnsc_b8dsWuAq1wQugKZA', 2),
#  ('-Tskf8WK17rb3ZfeFuRSWA', 2),
#  ('-TvJ8KJdXus3_o6uvG2GHQ', 1),
#  ('-TvOej9t6jCE7S7BmMZAqg', 1),
#  ('-TzFN6nWvbVRARY2B11Epg', 2),
#  ('-U-pHjIXOpx9__tmzOrqLg', 2),
#  ('-U-yRyAgo2JuKNS108XZOA', 1),
#  ('-U1xpWbkKmTQ3YCElPSW6A', 1),
#  ('-UADx0eR5Huq6s1CPH24Vg', 1),
#  ('-UJ7ZTb3zfmqZogmy3fnGg', 2),
#  ('-UPvmVCG5WQfLIA-p7KI2A', 1),
#  ('-UcTo6lcikO1IPmh4t2ObA', 2),
#  ('-UgmhgFa6biagbAXEPpNhA', 2),
#  ('-Uu4DGZTZPsfffQC2fpsAA', 1),
#  ('-Uxhjv9aZ-qE-2VDGXo4Iw', 2),
#  ('-Uzw3Hvy1KBNxak9vWsYyQ', 3),
#  ('-V0NjJcmkHxemSIW5_I5uw', 2),
#  ('-V0PfbZEa0HVTYxR4Rb0nA', 1),
#  ('-V0vIgo6196MDn_x3ZaYmA', 2),
#  ('-V4aH1YR67gdcakjCjU0bg', 2),
#  ('-V60XTbkUWtimOw5qTzozw', 1),
#  ('-VEGatH4Ea3anbCS4wjgIQ', 2),
#  ('-VH4B5o1sjZueC6go9FB1g', 2),
#  ('-VTHdEpkP_0Q7pMC5uemcQ', 1),
#  ('-VTvQDLzXrlntLdo-uLqwg', 2),
#  ('-VXcrZIhuVElGIgJ03Hj9Q', 1),
#  ('-VbtijUhH4xVP7cZbEo6-Q', 2),
#  ('-VcywFc95xKkt598Ujsapw', 1),
#  ('-Ve1jwEfMAd55KyHPcUzjw', 2),
#  ('-VlBFlHwX-Pt6Xyzs9roGw', 2),
#  ('-VqWVmXzLJJqVtRXAx_CxQ', 1),
#  ('-VvMsFD0W2nQuO9buaeC1g', 1),
#  ('-VxMtgvETrk7a7_WQu4gXA', 2),
#  ('-W0tnXYJ4WuxLjzmbwlVAQ', 2),
#  ('-WAOPYXWLomXvcX5Jtbz0A', 2),
#  ('-WQjN0W4CD5sw2DywN11NQ', 1),
#  ('-WXmyccE1YUqO3mA3Uu1Xw', 2),
#  ('-WY14B9U3ys08E9PwKOB8g', 2),
#  ('-Wd5KqFszREg0XdXfSv5tg', 2),
#  ('-WfGgYMcJKttsCu7WDrBrg', 1),
#  ('-Wg-4lsLfS3etcFDz6GPpw', 2),
#  ('-WgD54ji0_MgHWgf9WBXrQ', 1),
#  ('-WjTNKDYRyagBFCpHmkqVA', 1),
#  ('-Wvkgm0KtEXaCGlSc-Zalg', 1),
#  ('-Xey06RuVLCqClXwirk2yQ', 1),
#  ('-Xld662dL8WxrwP--bclIQ', 3),
#  ('-XnKdSHmeGifb4y2DcFXew', 2),
#  ('-XqH9MW831JOtqsJsrHEdw', 1),
#  ('-Xzvm1LxWyO7QZu9Q0UcSw', 1),
#  ('-Y-t4EXY68Lj6DqVFg08gA', 2),
#  ('-Y0d5ckFTrjvzxZCQoxhhQ', 2),
#  ('-YDYk83kO5ek-h4Fdu-Ugg', 1),
#  ('-YTipfQ0Yj0iF7m921rhmQ', 1),
#  ('-YdXf_PPmleD-8__gUnTjQ', 1),
#  ('-YjlbpEMGw_6VHAYH8gnCQ', 1),
#  ('-YljbQMbbTC9jwn8kOLitA', 1),
#  ('-Yy3mwrGPJ7GOUwZc7WU_g', 1),
#  ('-Z03-mJBBLoroXF7H0DLSw', 1),
#  ('-Z1x1qX_wIIckLkY7G__8w', 2),
#  ('-ZAVJcrczPaTVYa5KUUuRg', 1),
#  ('-ZCctA2zuUMxUihDwhYXAg', 2),
#  ('-ZJjxOYTWYbxD3yaz1CvCQ', 2),
#  ('-ZWx-IzLlKOMesKPix9JpA', 2),
#  ('-ZXjWCTxItm-3wPkgsf8zQ', 2),
#  ('-ZmzAg4-jR9edfePRSZfbA', 1),
#  ('-ZzCVD9Ge7KCy4ffhYkGZQ', 1),
#  ('-_0w82rV27l51N3ABkCI0A', 1),
#  ('-_LFA5At29YUr5Q48Nuf8A', 1),
#  ('-_WRjUCVv64YANhed_JGVQ', 1),
#  ('-_arFpHzoPHvh5p-YKw5fQ', 2),
#  ('-_jxFZVaC3r1TppArnlxZQ', 2),
#  ('-_mCgBtlEGbzbTsjnuXm3Q', 1),
#  ('-_oHNNTvb4gC1PXWHG8tVw', 1),
#  ('-a0kKyJPMw-8z5AjfQstTw', 2),
#  ('-aOD9iyZtkR9NS1l_-SJGg', 1),
#  ('-aXBwEc28UdpcNtl6B6sGA', 2),
#  ('-aZpjNPSNfTXYkLMkQDiKw', 2),
#  ('-a_rcDrFanuh8lDCb_DOqw', 2),
#  ('-ad35BhAZvtgrccfWI2kuQ', 2),
#  ('-ajYJZVvvaPEcCUgxfEnbA', 1),
#  ('-ajaASaDA_77I6pK3D4YgQ', 1),
#  ('-amp8lR3HxCw38XatBFT6Q', 2),
#  ('-b3VxSmRw1Qot8dtDLdluQ', 1),
#  ('-b56__bDEGYnCkCK-zOvKg', 3),
#  ('-b6YqNf1yR1ZJbDCsygrxQ', 1),
#  ('-b7A7e2zh3CDTpgChRoRKw', 2),
#  ('-b8iNhBez0hRu478nIDhyg', 2),
#  ('-b8qRoIcTo7NBgTAe9XhgA', 2),
#  ('-bGw8ARHQucKWEHEkxpGFw', 1),
#  ('-bOcJEs8imqtSXwG644k1g', 2),
#  ('-bR_RgtKytmFOHGPVUBcWg', 2),
#  ('-bUlpYP74Ei8VkSGpsltNQ', 1),
#  ('-bZQH8yjm7ntTyGeLQwh8Q', 1),
#  ('-batkL1-Uy3AREDdw3Dqtg', 2),
#  ('-bcnY0PELKRomT2z7eGQ3w', 2),
#  ('-bfJpqtlf2h0dfFFcVSHmQ', 2),
#  ('-bfRBexMAHt3p8wR4E2a3w', 1),
#  ('-bgu0iDSGLlYZoeRs2qdoA', 1),
#  ('-bi-PRIZg0ercEOnUcuiHw', 2),
#  ('-biTJUlMpAKAzROzhbuOEw', 2),
#  ('-bkbeuXaYdfM2APQCalgmQ', 1),
#  ('-bxLBGgtchd-O6-2CdDThA', 1),
#  ('-c6hc8kxFzeaIKoM6nWS-Q', 1),
#  ('-c7kNz3HjL3xc0LNBkTM8w', 2),
#  ('-cE9GrThz6HHn2zdpoqY_w', 2),
#  ('-cEFKAznWmI0cledNOIQ7w', 2),
#  ('-cGIFBCZWk9YgMWgHRaHrQ', 2),
#  ('-cXxMH_oL82mOK6MBAjOHA', 1),
#  ('-ceJoMSIAYcfGILikcqLsw', 2),
#  ('-d3GCAgDik9D-1YUM9w2lQ', 2),
#  ('-d5f0NfB8E6M69kze-pbsA', 2),
#  ('-d7-1HgBBu0dcdp26DEW-w', 1),
#  ('-d8B04ueyxADRutlcHYewQ', 2),
#  ('-dB0vYhiTeBDlayTzT9kiw', 2),
#  ('-dEuJqTHuE6rv8MrndqoXA', 1),
#  ('-dQmz_R27erIuM5qR5jKIw', 1),
#  ('-dSJmP8UtK8X3K5QWgtW8w', 2),
#  ('-dVBeSZxtxpHQ3XdL4E4bQ', 2),
#  ('-dlU_Vr-5-szuLZteMWy6A', 2),
#  ('-dnDk3b-_JNpfzgtX6EOLw', 1),
#  ('-dqBgugu2e6EMibkGWXVrg', 1),
#  ('-dsxu0V5X7OD17i8HcQovg', 1),
#  ('-dwqsjGDBnzzv2qQYyIC3g', 2),
#  ('-e03PAS1YpMAaxp86Hau7A', 2),
#  ('-e1BUAOBk9RAu89c6uTyGA', 2),
#  ('-e25gkrazUCBqcSdgsmHGQ', 1),
#  ('-e6JPq8mFkMQQoWyANSgrQ', 2),
#  ('-e7vSLH84kk7mzHsesL0Qg', 2),
#  ('-e8idMo1i2j6AUyKm-UBzQ', 1),
#  ('-e9MepGs8piOYdwuP5x7tw', 2),
#  ('-eAmwxqpedMfAHREjJzQLQ', 2),
#  ('-eBDRVn1mPwHFCF_hry20Q', 1),
#  ('-eKkqO8t3wGe7MqGGEapUg', 2),
#  ('-eKoPT80NewUNc2h-hevdA', 2),
#  ('-eLCHvtz99fc985UNL1rTA', 2),
#  ('-eQIylvCo1gYDkHcIJs9EQ', 1),
#  ('-eZ7NYqKCwIAY__MHkcGBw', 2),
#  ('-ebwX4cjBDsZtPnvW1M_BA', 2),
#  ('-ee5czr21mfEJGrbZ-572Q', 2),
#  ('-ejuzGbu3ZHUndhLTQafJg', 2),
#  ('-f43-rglIkI4AIowaJF0sQ', 2),
#  ('-fCB9irkaglTWG7rBhcODg', 1),
#  ('-fEZQoE-pdN_uvXdr3WR_g', 2),
#  ('-fJHTVafUBfsTOH_bopDBA', 2),
#  ('-fJPJP7iOd1ukDNqTSINIg', 1),
#  ('-fXwu3Xc3jI4cq_uptjBCQ', 1),
#  ('-fciE0b98A43i04VIEDlgw', 2),
#  ('-fonJAr5xCGzFfER_7CsCg', 1),
#  ('-fxH1XplVLVtWg2ZJWwRdA', 1),
#  ('-gBEVHYMm2aRln67JMEufg', 1),
#  ('-gDkE8UgpNuD0wJUESH66w', 2),
#  ('-gFkkYh0tqQcgZh3z0yyYw', 2),
#  ('-gGywiFaJHb84GxW76DIZw', 2),
#  ('-gJ3m24voBGR-8fS_hQN9A', 3),
#  ('-gZPRSuaHJG7PYHAGFmqdQ', 2),
#  ('-ge1vRtSm_k_SnB7I4_fhQ', 1),
#  ('-gikv6T4uE5GvpZ7iQx-Pw', 2),
#  ('-gx2zqPkSs-7aGZ01bDb7A', 2),
#  ('-h2ofCKKVch8fyinQxTsGQ', 1),
#  ('-hVMfjPPEsSnga_gnYJx2w', 2),
#  ('-h_CLzSZJGmSHBNk2LXShw', 2),
#  ('-halGT88LFZtC0Z-UXjJpw', 1),
#  ('-hmKv6MRLgpbUJqGjyY5xA', 1),
#  ('-hsR1sWeD9Vw_nh5Qym2fg', 2),
#  ('-hto0uJjh8KFQZGc9ZAcuQ', 1),
#  ('-i0FqsGq2B-3FR-p68JfDw', 2),
#  ('-i0nH5vp4oeoRpkVGfAQSA', 2),
#  ('-i9AaoasqTUb7WmCSftmKQ', 2),
#  ('-iGzevsRYAi990-Lt-iMoQ', 1),
#  ('-iOgafQZPQAiLJZwegPseQ', 2),
#  ('-iQdl2pQoJQUbzC42ld7Fg', 2),
#  ('-iXlYo2AI1iHgpeZnv5sPw', 1),
#  ('-i_Q3Zo1SxqoQu75T9nNjw', 2),
#  ('-ib2qJmDKJgH_ZbtSu_HjA', 1),
#  ('-iclF-OurSdeL0qcHhXuww', 1),
#  ('-ikBycdroyTLDBHR9aC3HA', 2),
#  ('-ilTnXu41RrxQITuolQhmQ', 2),
#  ('-imlMPrEJ8cc99qjEclKVA', 1),
#  ('-ipZBVF9nWm1vzrvQ3444A', 1),
#  ('-jNOHaFwWsBpaf9l5gvRwQ', 1),
#  ('-jOBLBltG_33vpnXdoS0bA', 1),
#  ('-jkc-0YYvwkBaNnNyiUHNg', 1),
#  ('-jo0DZIkxfXuvcWxJP5VeA', 1),
#  ('-jrT-2bTSDaqJtzHRpY9ag', 1),
#  ('-jtTmbqX3jeMs4z693SO4w', 2),
#  ('-k0SQn1uQVn0FN61uXYMsw', 1),
#  ('-k1iNvlyQZkZ14Hcqzlk4Q', 1),
#  ('-kAaeJxXCtLNAo3DosoXXA', 1),
#  ('-kDNAKwvtYcW0NMjHRmgkw', 1),
#  ('-kFTv6W5q8-SM5RFkV_mbw', 1),
#  ('-kGUmgyeYcNDcuEr4FoVeA', 2),
#  ('-kHHi8y4kaTI6WUVdJSdvQ', 2),
#  ('-kIJmSUZiBygYu6KYWHGQg', 1),
#  ('-kOUmMiIimNSBIDdFN0x-Q', 2),
#  ('-kRlJ5_TxIeHoqNSMNBlEg', 2),
#  ('-kRtI79gCFWX__CvFNMmoQ', 1),
#  ('-kRwGI1Opy0FWhq2z-4D8g', 1),
#  ('-kVGt2QRNtBoZMvKeIjVug', 2),
#  ('-kWKHxA5tcrCfbfx-_OLhQ', 2),
#  ('-kYESienondGaj9TFadkUg', 2),
#  ('-ka45SR1nuoxUU4eTamE_w', 1),
#  ('-kfHz1kimX62QEceFkkB_g', 2),
#  ('-ksLHy9XXZVYuIVowdRc_w', 2),
#  ('-kz82pLe268Cw59S6fD1BQ', 2),
#  ('-l-FYsn2mCCDKTTS-uqssA', 2),
#  ('-l3G5kG-LuiKe6Eqy3KKZw', 2),
#  ('-lCAkuXEbXVO0gG4yNupZw', 2),
#  ('-lHpvtlMkRu0oRIXJkystA', 2),
#  ('-lLEaycKOdFoPALPL33NFA', 2),
#  ('-lM78iJEh0GH5MkgE-_u5g', 1),
#  ('-lVEVi3vtQ8_L9kKT0bBwQ', 3),
#  ('-lVTNjVoTMOkD-eT--u0oA', 2),
#  ('-lX4ufgPLYubI8rVxNM31w', 2),
#  ('-lhHSR1Aws4CyYC1XOPVTw', 2),
#  ('-ljWGhdLY4QD8y8h3R-rJA', 2),
#  ('-loV4cB2Uh9TCltTRgGzWQ', 2),
#  ('-lpV42lgu8mBfKala8bihA', 1),
#  ('-ltRJOR-r7MhOh7g48HQwg', 1),
#  ('-m44EXqIrdQFYpoH43Sifw', 1),
#  ('-mBc7M9Q3fEIxuUxwOleZg', 1),
#  ('-mDAFyX5kZHXhxjELeMhiQ', 2),
#  ('-mIlmp5l4hKlp1tvHRdvTg', 2),
#  ('-mX0wJKh5uW1Kvd_VFFqjw', 2),
#  ('-m_fl--6j4DFv1RlOtuL1g', 2),
#  ('-mcTFLh291MWYECT2bAr3Q', 2),
#  ('-mgekT-JE2duBrene6XXjw', 2),
#  ('-mhDGGy1PgKLDZJZHQZsHg', 2),
#  ('-mitV3FhrCz3m2wk8ldKDg', 2),
#  ('-mpK4taJ2aEhqdC7DjxUnQ', 2),
#  ('-mq1DwgcLU96PQbmcv3jRQ', 2),
#  ('-n5AeTiDdNl5rF0cJOoNbQ', 1),
#  ('-nC9g_6S8kPXFNyee315hA', 2),
#  ('-nEsM53i_wmt9wpSlQm1Rg', 2),
#  ('-nFhHFySIOCBQW4-zHtnHw', 2),
#  ('-nIXhxPvxST6bTuj9jo1UQ', 2),
#  ('-nJid5B14dYu1wPtMp149g', 1),
#  ('-nUV-Z7_RdHY1dLsnuo0xQ', 2),
#  ('-n_beuzQuajaezPD2PyQvA', 2),
#  ('-nhK5vmY9WU7W5PCXLpfkQ', 2),
#  ('-nk14DuVMog4IeCPNF1JpA', 2),
#  ('-nkHF-cspbXazYeg4wIGhA', 1),
#  ('-nkY7ja6K_Zu4DLC_VeeIQ', 1),
#  ('-nkdsrNAQoHEve7j_k-_qg', 1),
#  ('-nwNPb3G-0L95igrhkvMtw', 1),
#  ('-nxsgCv8aqXPoRkdnT0soQ', 1),
#  ('-o6bah2j6_IH9pkwANXcLA', 2),
#  ('-oLUNNkVi0Wdikuc4LlQ_Q', 2),
#  ('-oMyiUCsLxFvUxHvPM1hJQ', 1),
#  ('-oULvzCU5o1Hwr28Cl5rsg', 1),
#  ('-o_MRjr1VtjW4ZdrDX9o-Q', 1),
#  ('-ol1560JbWGTSu6VjgsW_g', 1),
#  ('-ol8_w6-ArmKBw-GMK3NkQ', 2),
#  ('-ovvV-tXLQdXyYgdCBZm7Q', 2),
#  ('-p1n0tJURpNW5vwM0dGBcw', 2),
#  ('-p70N-1fbYVz3NSffvd7UQ', 1),
#  ('-pRU97z3uPU_M7yUf5yzMg', 2),
#  ('-pjWlAzv4qRxB3Gu1D4t6A', 2),
#  ('-pqNA1evZnP_4eTlAOJj0g', 1),
#  ('-psZLTe6IJTQUB-bZF7Zyg', 2),
#  ('-pyEgpSarPYwbclUdxk2Ig', 2),
#  ('-pyobEWdpZ6jUp42f3I2xw', 2),
#  ('-q-0cRcMJx3S9fgDizF8BQ', 2),
#  ('-q4YqKsWJY6NtkQdnNeL1Q', 2),
#  ('-q8Dnex7CtMFkg04gDd09A', 1),
#  ('-qEk9byAfXQvKNVK1tCitw', 1),
#  ('-qJUOsOCwODgEumCrQatTw', 1),
#  ('-qNVtEd8Z9MtCfC5dii6nQ', 2),
#  ('-qP1L9kx0FoH-kFwHXEwbw', 1),
#  ('-qWhas31o61V6vC6yo6NWw', 2),
#  ('-qXHPxXkzTxYSelS4nLOhg', 2),
#  ('-qgxOFSNmpuyVIK-l0YCsA', 1),
#  ('-qk__vjJxfJrCWn3UaMv_Q', 2),
#  ('-qpFT-RgBE2QXVcSjq57lQ', 2),
#  ('-qtgI1xDDSqxtTtPn3ERHw', 2),
#  ('-qzHEErYuwly3XBGlVZy8g', 2),
#  ('-r3NgzSEUuVjV9PLI-2ssQ', 2),
#  ('-r6AXDYz2rG6wcl-u5rZuw', 1),
#  ('-r6nmLB5Vi2TLQCxh0_dtw', 1),
#  ('-rBLDkfHNXV8LzofwLcjHw', 3),
#  ('-rCB_kCW-u84S-CQir-lng', 2),
#  ('-rDN9oCIZmmL6nM_NTDQ8w', 2),
#  ('-rDhWLQJ28L2ttkaftdZNQ', 2),
#  ('-rTJCKclkU_ZnoQb4oKa9w', 1),
#  ('-rW8eTXkovH1NksTZzJ7Yg', 2),
#  ('-reeXxeQfRSvO7NXOdgKcg', 1),
#  ('-rf-o_H-3_6XUrSxOLRcpg', 1),
#  ('-rwfGlw6T5czqQO4uZGWYw', 1),
#  ('-s1TSRhuQXh0RQJhaFB1vA', 1),
#  ('-s6EMVPCBrsocFDuiMMqxQ', 2),
#  ('-s8G4_7aF8IxlAq6p1w4rw', 2),
#  ('-s8NdZJQEeJoPYBw0GFcKQ', 2),
#  ('-s8cHUa89WF4A5JWZtAAhQ', 2),
#  ('-sSGKR1V1oBm7BJicIXozg', 2),
#  ('-sTrihdzACrsOSu1FYdfxQ', 2),
#  ('-sUHs1vO_8lTzm9tstM4Cw', 2),
#  ('-s_ovV4hkwgfRdjEp0ZXMQ', 1),
#  ('-sfymVvHA9TS_8V6kvvz5A', 2),
#  ('-t1hxZ6X-XaIU4BBUQCXGA', 1),
#  ('-t29rrypP0eQdTeQ3YErdg', 1),
#  ('-t5dx3X0O63jCUuFEd-FcA', 3),
#  ('-tDmeO1Q5aqThVY3AFJJ7A', 2),
#  ('-tRhEoFo5viTTPX316ut6w', 1),
#  ('-ty6wdbyYZvS6remymbdvg', 2),
#  ('-uH_A0CIUlOdAhGgCkpd1A', 1),
#  ('-uVvRy08ry6C_6vkxih7vQ', 2),
#  ('-ucEQFPRCfutQpPFBCvjbg', 2),
#  ('-uhn-iY4lJvWqoBXDghjZA', 1),
#  ('-ui0RWrHmm4DQPFMVh2_Yw', 2),
#  ('-urxhzobcJtOpgFAyaEIpA', 1),
#  ('-uzQNt-3jsRK5okUuJiQLA', 1),
#  ('-v0JE4wW_4Xs6C3WT2XgDA', 1),
#  ('-v1Ia8G_G00SuygAm6koUg', 1),
#  ('-v23pO9PUja15AiuUOW6tg', 1),
#  ('-v8dtO9BZmKidXLMohiQhQ', 2),
#  ('-vOvKRm0kK6r3moj2l10Lg', 1),
#  ('-vP_oH77aIgqITqWKn9uog', 2),
#  ('-vSkeoIujNpKhITwvcYVLw', 2),
#  ('-vXGKRBI9qOtNLoptRyaHQ', 2),
#  ('-vZOSS6imzFSSOskgSHjpw', 2),
#  ('-vbvT-Act1BqND2QfF7vlA', 2),
#  ('-veGIq3SvwFMi5ZwMSIqkg', 1),
#  ('-vw5_lpIfc1hGyMn8gIYFg', 2),
#  ('-w31kc6pp2m0fzkTollj5g', 2),
#  ('-w6v6xauapvUMhKf1kyjFQ', 1),
#  ('-wB5H63ERJ9S0oCp_ULR0Q', 1),
#  ('-wDFSijpAhNAuKXnp6q_-A', 1),
#  ('-wDo0EQLaobFdkwizA1i6Q', 2),
#  ('-wG5DQxGlSog4ynKrRdQMQ', 2),
#  ('-wH3eQQl46pUsKIcTTY0qw', 1),
#  ('-wcyPLzR81b40sCMmZpi5w', 1),
#  ('-wjASAa3rySsmY9CIGRm9A', 1),
#  ('-wlmZ-b35UJ-GY-59NDxyw', 1),
#  ('-wpjPXundFyZCm9khW2wLg', 2),
#  ('-wwhD6SwDOJZlbZkHlIchQ', 2),
#  ('-x2B-rrTqqLMrcnzYuQlpw', 2),
#  ('-x7YizC9UmmjMuSGxrw1LA', 1),
#  ('-xCC-SRYR8mA-_KU0Yi32Q', 1),
#  ('-xOLxvu-xEUXPKSW263oNQ', 2),
#  ('-xUN3uoiStSO629KcFDLVA', 1),
#  ('-xUj6GtnPLmf5zwHz7ZILg', 1),
#  ('-xV7aMI1PHEaXPLCA5H2ew', 2),
#  ('-xY4R0jVwIDlpFx_CcZ4XA', 1),
#  ('-xd2u9BsEOy-CVKopm4VWw', 2),
#  ('-xeTwslZeVQ5MhcXIVIMSQ', 2),
#  ('-xhTcS5y-7LwHPRfBxJhfw', 2),
#  ('-xiLPlI6JVm-W2DFWpN9Sg', 1),
#  ('-xov4QrIEkyNrSArhjmjZQ', 2),
#  ('-xtnwq4VBA2XFobjDGz0Ww', 2),
#  ('-xxPdDMPm80ogHx_hgishw', 2),
#  ('-xxUhiJ85XoAC1St1o8wWg', 2),
#  ('-xzkqW1y4L9PTAPJjJu3yQ', 2),
#  ('-y-ZAPuuUN6cbQtFoqiPFw', 2),
#  ('-y05MW4mCci-eSv2yJkzzQ', 1),
#  ('-y5vYOsyL4bSFxeOtQtYbg', 2),
#  ('-yCrdNTk4RzUax2FJusa5g', 2),
#  ('-yFbTwzGllU3kHfRmJWO0A', 2),
#  ('-yMcp7py0eWNHBUZ6sxvNg', 2),
#  ('-yQIm7RUM9AvRA-ycnejjA', 2),
#  ('-ygugwY5-_bYrOwN_jo9Ag', 1),
#  ('-ypIPYkJxDeAWSTEq530Mg', 2),
#  ('-ypNsJk3pCyI_mehvMcrWQ', 1),
#  ('-yssBdSPYgvOWUhPjQOEcw', 2),
#  ('-yu4koRugjxrnsey25oIuw', 2),
#  ('-yv5rZal-wt9o5GlYOIZpg', 1),
#  ('-yxOY_fhwp4uss-8rGTGcA', 1),
#  ('-z488XvNmHIn3yv-3N13oA', 1),
#  ('-zGlHyBaxib9p7k18i5TSA', 1),
#  ('-zH42-1AauJru4EF-s7Rgw', 2),
#  ('-zJfM9nlw0ljqF8Xpfa9og', 1),
#  ('-zbTnIz1zPNPmKpO0bmEvw', 2),
#  ('-zkta7usVyQVwH6CHH7Agw', 2),
#  ('-zngCcpYYPNXEfwv9NJsIA', 1),
#  ('-zsvmEbkd-K9K2DAAKqiEQ', 2),
#  ('-ztdG-hhxduK5Cgk6gTTgg', 1),
#  ('-zvDhu_Sgw9HmlO54zI40Q', 2),
#  ('-zzAC2cpeUbr9QTwy59yvg', 1),
#  ('0-3NcAbA1zeChqWeH454Ng', 1),
#  ('0-7N3z_cb3Z1xMGDrbez6w', 3),
#  ('0-9PkkpEM53bTgUQo-ls9g', 2),
#  ('0-BLZd37lMUODMuYAtKgkA', 1),
#  ('0-CQlqMMOrwMhy4EgW4tfw', 1),
#  ('0-JRAY0LpBazDuA9761U5w', 2),
#  ('0-Lihni2Ak2RL6RwHb4fpw', 1),
#  ('0-M3vGd6IveJh77-Bwc8EQ', 2),
#  ('0-PClaUWGphUvuTH8wQ51w', 2),
#  ('0-ViWW1_-_TKIf-o8o8bPw', 2),
#  ('0-XYsSxJhu8ayKx1f3v_tA', 1),
#  ('0-evjpRKnht75t9J3NE8Zw', 2),
#  ('0-kdvVEyfkusVeWQVC5mqw', 2),
#  ('0-knl9jhkJnseDvsrUpFWw', 3),
#  ('0-nBk6dQ1Br9GOoqdr1bpA', 1),
#  ('0-pY7oEuTT6j9fa1k-YBnw', 2),
#  ('0006EuNe5LBARerF4RKz4Q', 2),
#  ('008FLyatMEsZzmmKALIgDg', 2),
#  ('00AGVWzkxNLGb-7ZrwAOIA', 1),
#  ('00ZHPWYGtJTY8zqfTfP_2Q', 2),
#  ('00eSqUS2r4pm0dFZhZ3d1g', 1),
#  ('00p_pZP6l7HQen1Yw7alkA', 1),
#  ('00rIcvqmfci_oJWkOqPqmg', 1),
#  ('00rY5F9ltW-IWf2Ev96kOg', 2),
#  ('00raCkd-MBw7n7lVKOb_oQ', 2),
#  ('00sOoojttpdZljH8VgOU0A', 1),
#  ('013W_M4YUTo_pjXc9J7KvA', 2),
#  ('015DpGQSGAjbHfa7KE-p5A', 1),
#  ('0169EQn9SEi1bocoX5Ps1w', 1),
#  ('0171xkyBr0rxKRGVIBGmeQ', 1),
#  ('018ixB-WinNmflwX2UvS1g', 1),
#  ('01FJ5If8zeDa-URdjP57eA', 1),
#  ('01JQ8CecavDWtxVTsVXKqg', 2),
#  ('01QBBeOrR3shusGKtsJNQQ', 2),
#  ('01TorM6wcQZUZ19BOC--8g', 1),
#  ('01Vnpln40zgSK6H6pAcd5Q', 2),
#  ('01Vuw9VgqJVIwThiGg3sRA', 2),
#  ('01YFYYmevGER3VJ1xFtUcA', 2),
#  ('01Yl8rIjOsaLrwre78jugg', 2),
#  ('01_VHKfqXzMXpnCm8Y_InQ', 2),
#  ('01ikDdFTvc2-YXeyv-YXjg', 2),
#  ('01mP5a06zQpaYOakfaVBOQ', 2),
#  ('01pmVUeVeXKtxdnLcQrUOg', 2),
#  ('02HdjzKf7pUujFqYIvKiFg', 2),
#  ('02PoEXj8TR7FQZvUV48o8w', 1),
#  ('02_C-qiV1wJbT43mgx_F5Q', 3),
#  ('02_xUzgLL2v67M3e9GJtLg', 1),
#  ('02euPBQRCGkdt2AnJQzJUQ', 1),
#  ('02exrrOiVaTnrRXQGaYCDA', 1),
#  ('02jAPgIHC9LPqOEtdS57SQ', 2),
#  ('02jZC7oX0SbWXVFboNwFGA', 1),
#  ('02kw1y-cUK5v_u5BaAQvjg', 1),
#  ('02nb6CI8w-2EoSEkQdk2Wg', 1),
#  ('02zmTFH6P_u2Z_TISOVNFA', 2),
#  ('032C5jJEFFpatebqap3LRw', 2),
#  ('033Ok264muClFlaWFeqo9g', 2),
#  ('035gK3ASKDns-ojUSnV4IA', 4),
#  ('036_95rJbB7PvCHfkCL6Nw', 2),
#  ('03K9F1xumPgdRiohRrXyfw', 2),
#  ('03VF_TH3w3ziSL4yDgJ1CA', 3),
#  ('03YfclexPdS_yrIbU6ahaA', 1),
#  ('03an5ytHalUpCjfN8vcjRA', 1),
#  ('03bT1qQMKMIXJSCGCRv1Wg', 1),
#  ('03cSyx_R9s0_3e4jyM5CbA', 1),
#  ('03cvVjbkCOtiIt51M-MLFg', 1),
#  ('03dIEDBsDERr6Osmey-udQ', 3),
#  ('03eK3cN3PoumXIRs06nZnw', 2),
#  ('03jQGGJ2ch0uHTtW-UUUqg', 2),
#  ('03n4m60mWxQyNaSilKlEkg', 1),
#  ('03sqfUjXdEtZCUxVFxXntQ', 2),
#  ('03u-wHrKSntiQvfxs4z84g', 1),
#  ('03z1PDwgKroME5MWr763rw', 1),
#  ('043dEkNUPKvG7VsI0nxi2g', 2),
#  ('04Ss49U_QKYLotcJMAH8cA', 2),
#  ('04UD14gamNjLY0IDYVhHJg', 2),
#  ('04UWD_QOyfn-NxcQ04M0-g', 1),
#  ('04WpqoyyuqX5IrgI-gAAeA', 1),
#  ('04bnx8EOir7t3k92a7DV3Q', 1),
#  ('04l8PYcuYQeEkEhJCbhtOA', 2),
#  ('04lEB3_tQGky8dq5kCa9Vg', 1),
#  ('04o5d9u5NnS2SsOxkKos1g', 2),
#  ('04o5yH6y_49RkLuEaiW5mg', 2),
#  ('04pgBRwtIZiD4jITp2_4Ow', 3),
#  ('050qnpy_nvxRLBR11HtEHA', 1),
#  ('05471AhNLv1NxKoaVs4gYw', 2),
#  ('055MXBjBRCCo3A7SHmR64g', 1),
#  ('05GLPgaqx5y4H9dBU6CP2w', 3),
#  ('05J_7mQg7dPuaSB_BBYEOQ', 3),
#  ('05UGAUzE88mcPxQ7WnCxQA', 2),
#  ('05aUWoz7IpdMnViLQWE-bQ', 2),
#  ('05dUFDFPr4St3SOi5t3fiA', 1),
#  ('05ev984NYfimRN0UiFrxaA', 3),
#  ('05kzzPzP0VEMdJi_D7Th_Q', 1),
#  ('061FpJWUbhSFP-ZEXSpdGQ', 2),
#  ('063-mwbEdc9J4h4QqEdpvg', 1),
#  ('068DMaEKghlGsSzJPuLucA', 1),
#  ('06Fw40aGMI_sInznweYLow', 2),
#  ('06NHXjVHiGKNpZ2XeajVkA', 2),
#  ('06PmqoU3uY5Vb-BEaMPVfw', 2),
#  ('06_ObrhBE8qd2puOu-lkiQ', 2),
#  ('06ddjGdyYk580UtBwyfbdw', 1),
#  ('06mrRuzYE3zTcVqDDPvzNQ', 1),
#  ('06pNHtxgPhGhZpM0Z2uzNw', 2),
#  ('06s46kJWbjIomKy_j-slew', 2),
#  ('06w-nCn3voKD69dxGxYn-A', 2),
#  ('06yarCUo6OBNAIagXjAp_w', 2),
#  ('070Sixz8aXNoSbH0-49PDA', 1),
#  ('07D-uYB0PrSYUVpbKeojJA', 3),
#  ('07aiOK7W40KIAgEYeHES_Q', 2),
#  ('07i5EdI8v2FBhVV-rya8Wg', 1),
#  ('07j0eaVt1aggrshdZqHhIA', 1),
#  ('07s3mxO67e8L8k3tFz4oIg', 1),
#  ('07tT34LEBj1xVgLRk4L8qw', 2),
#  ('07yUvKzFb-yPzJKoT0zamQ', 3),
#  ('081vVr80-uscqGGaFAxKfQ', 2),
#  ('082QyZ5EwWNU1DQKOQsdzA', 1),
#  ('082Z772_Ig8SXp9DibYCAA', 1),
#  ('083FNb_RWY56D0QuQXTD_g', 1),
#  ('085BE1LGQVyuHEsr5AeROQ', 2),
#  ('085mjp-y4qmKRMIj72x8xw', 1),
#  ('089KGIJDnVJEAe3GiXzlrQ', 1),
#  ('089cd4KNxpZ0Ii1tJps3Sw', 2),
#  ('08LQAC48MVFa27YZKahEkg', 2),
#  ('08SYU1uLNCned0Oyrh06JQ', 1),
#  ('08XjRgU24kHcikWd4Rg7rA', 1),
#  ('08g47fCB89MAbqIpRI-QQw', 2),
#  ('08kBMcufQMg-Dc9IouWIYQ', 1),
#  ('08kVZ7eYC9NGn6njjsRkQA', 2),
#  ('08q4nEOcz9hc1lRW7UPOng', 2),
#  ('08zAKV1Sp-TIC_YVwBcBNw', 2),
#  ('097galLQxX-K6j0HJAUKyw', 3),
#  ('09eFzvizdEQlEBvitKMhmg', 2),
#  ('09izIShLukoy36bBOWfKAg', 1),
#  ('09uLsAhgFJEPJl2dZHX2HA', 2),
#  ('09za1h1fdeF9rTSviTV3zg', 2),
#  ('0A2w6ViIzZ-T-pB1a8da6A', 1),
#  ('0A7a_1DwgrSffuMc1yqF1w', 1),
#  ('0AG_tGzuGKpzqwy4daddCQ', 2),
#  ('0AH7Sc_dLol7P4dYlO_jpg', 2),
#  ('0ALY2NFAhLWeWYw1bh3eJw', 2),
#  ('0A_TxKByQxEbQNr_0tpHbw', 1),
#  ('0Ae7F98kmeA01VJCIdD8vw', 2),
#  ('0AfjyySl4Rivh-QhWfrClA', 2),
#  ('0AgwjiluvSLEkpHNJe1EHg', 2),
#  ('0ApzFj5gwCg2E0wwq2RyZQ', 2),
#  ('0B0L4P5YGgbNeb7Koyez9A', 1),
#  ('0B4YRxRp3Ra1lZcWrrccvg', 1),
#  ('0B6JY3Ky8iB52-rPooB2Tw', 2),
#  ('0BAwhsPK4Zads8hOFXv4GA', 3),
#  ('0BJy9The-xE_M912gkwDHQ', 1),
#  ('0BMb_vELxCCH_kJz3cVjdw', 3),
#  ('0BQXBHHFrfg4RZIVDQbPig', 1),
#  ('0BTyvVxvayjOX6y10qIvtA', 2),
#  ('0BXnGq6eJuiWR7270TipoA', 2),
#  ('0BgrDm4tfQBtlEV-ZqtAtg', 1),
#  ('0Bn9pMb_qcBO5mZYa3QAEA', 2),
#  ('0BnjHJ8H5F15KjeMgDCBAA', 2),
#  ('0BoRHt9GuiXzmvNmrBVMOw', 2),
#  ('0ByzGehS0T5muzZ2qYGq_Q', 1),
#  ('0C3T3J5AWrHTkkq3K5oFwg', 2),
#  ('0C3ucRygW0uSHfqFENa2zA', 1),
#  ('0CEUpFtaKhxbmrbSdP9MUQ', 2),
#  ('0CHIbqSkGWBr2KMkIUocEA', 2),
#  ('0CLCzdedGT2DPjkYM52Tqg', 2),
#  ('0COlL5IKRu5sdWIsEiQAZg', 1),
#  ('0CPhgQAtXvxsmyFNJah16w', 2),
#  ('0CSiz9Q_xuZ9YNq8KLRcSg', 2),
#  ('0CeDwvLyRVgr-fq-DHk1sQ', 1),
#  ('0CekZnAtUUuyKtT6pFwpXA', 2),
#  ('0CennNWmhiYdSOEkGr7vkw', 2),
#  ('0CeoONLXqseUxPdGerefOQ', 2),
#  ('0CrEQpPKHfmjVodZeyL7IA', 2),
#  ('0CssPu4DgIImkouHXKTY6Q', 1),
#  ('0CtK6VnXGOQbZ3sUXSdjPw', 1),
#  ('0DBf72U_oR_iDDXdOx4a4g', 1),
#  ('0DGml7Gd-6M4iakHdDqkSg', 2),
#  ('0DPQukWX45rqOIfDV40e3g', 2),
#  ('0DbIUh_Xuj6H5B_SF0RLCQ', 2),
#  ('0DdmKihJ90qKP5TAM3c2yQ', 2),
#  ('0De2juaQqHNUYs-vNEj9RA', 1),
#  ('0DkIUiK3hkM1stV8AZ5ULg', 2),
#  ('0DpVMoXMvN7vtGDCzNy57w', 1),
#  ('0Dw-i07FHf-PLLIBA6Xa4Q', 2),
#  ('0E2JLWX2h-GdZp8sliaKcQ', 1),
#  ('0E4Qo6Glr2pWkF6L9MJqbA', 2),
#  ('0EH0WBJSqVvu0vyVUM2zBQ', 1),
#  ('0EPYrxeMLh2G63HLMIgRHg', 2),
#  ('0ERS4_k61Ea7VVunLcxlgA', 1),
#  ('0E_KdunEgkC6V7RgXewmXg', 1),
#  ('0EbYHXAKFo9IsFhmZHD1Nw', 2),
#  ('0EmBlyDtgE4_-AYK5I9dPg', 2),
#  ('0EpCmB1qbtH6Xh1RgBnQaQ', 2),
#  ('0ExninKCazSHWWU-7QOXow', 1),
#  ('0F1WFFm8TJde117UZPbkfA', 1),
#  ('0FIfHHrNbcc_hXbCjhU8HQ', 2),
#  ('0FLi2UPWY3bTvrcuTWG5IA', 1),
#  ('0FQKOh13Tkcfgbu6qeZtXA', 1),
#  ('0FVZYtFtnysTgBXzPkS7CA', 2),
#  ('0FY01rD5zW9ijsMNP-HV3A', 2),
#  ('0Fd0erJKcQlbnWnPrYJI2Q', 1),
#  ('0FnYxHXn1dXyuKFNWhz6sg', 1),
#  ('0FqqWN5GMdqzF9JnwH2ulg', 1),
#  ('0FsYHx6mnD0rx4IeRAgROg', 1),
#  ('0G25IDvgvoqASYsqu0HbCw', 2),
#  ('0GDLQWC_Ptm5U8eiKmtQTg', 2),
#  ('0GQ1O0vmmLiHWB0y1JM-zg', 1),
#  ('0GSUrqeDBwJoZXxTAnmy-A', 1),
#  ('0GYqOZwfs9eZGLdb5HCFLQ', 2),
#  ('0GaTpDXVFTxJPQsdRLVidg', 2),
#  ('0GnmW0__mF3m7_KHRaYcAg', 2),
#  ('0GpoYiUGa1okXWdhEweDdw', 2),
#  ('0GsYSmfpsUpnTnxYbH045A', 1),
#  ('0H9q2x77DeEN_YbGva2SjQ', 1),
#  ('0HCMp7WxB7ZWtoVl5qGl1A', 1),
#  ('0HCZGBYG5q5Omu_1c5V7Dg', 2),
#  ('0HVo5yYbv60WgNWfrVoXlQ', 2),
#  ('0Hdvz0Ups_nN9kIb3uo4VA', 2),
#  ('0Hfc9kXBJJAXk6XxDtoJMA', 1),
#  ('0HgAYe8KZ_8nHyELHFwrpA', 1),
#  ('0HpHVZFlEH5csxSBRVSmsA', 1),
#  ('0HwxZ9ngr_2rsnuawVOocg', 2),
#  ('0HzjYHjeL5GvGHMj9XjO5A', 1),
#  ('0I9XZD7JTqY9iTF8nXRnXw', 2),
#  ('0IEn6AxLNFfdfuwd2bQlbQ', 1),
#  ('0IFmbpwP1JiWVCG7z9KORw', 2),
#  ('0IG9w6YCkh-z5pnfSip6Nw', 2),
#  ('0IHBQ3G-E3IJFaDSXpLlBQ', 1),
#  ('0IKbUmLM8pWn9t-Epf19iQ', 2),
#  ('0INrDX--UuVvHVKpk4mL5Q', 2),
#  ('0ISLfrUTkpBmBubu_n30dw', 2),
#  ('0Ib_MPoFNwXnfKtNOjOx9A', 2),
#  ('0IcEAPMDFDVJ8d2UvYOkEw', 1),
#  ('0InojtGES0EuD3hfXGoeow', 2),
#  ('0IobJ1t-wkqqKoc95AAj2Q', 1),
#  ('0IpMsvaHqob_ks3ZhuLqzA', 2),
#  ('0Ixwu5ukFhC5WU7viCf_6w', 2),
#  ('0JGG50I4c9iAPrk7H8dRcg', 3),
#  ('0JL7AdnqRwgBXdk7Nca5UQ', 2),
#  ('0JPi9cyV9i3_kDPj049_qQ', 1),
#  ('0JQgHiPAQQWkdgbBvEL3JQ', 2),
#  ('0JX2lHSYOr18lwZqZ_BIWQ', 1),
#  ('0JaJPPwiltLOLC6IEjjC1g', 2),
#  ('0Ji6OV6UKSOeF1ylu_ukgw', 2),
#  ('0JlxuzzDo1Sv89S9ApI9Ng', 1),
#  ('0JmFfcBbIux_vauRNWzD9Q', 2),
#  ('0JnsAQFvOFxPltNU_smK3w', 2),
#  ('0JoB3ThhI-DS78-1Ks1EUQ', 1),
#  ('0JpbgItuNiP4KJ4PQ3YvRQ', 1),
#  ('0K-z6hRV2RhvEC3z9GFG7A', 2),
#  ('0K4RwxdAcViifyU3Htzxww', 3),
#  ('0KEMPs7BD_WHI6zGpDcKjw', 2),
#  ('0KJrzznRV2eSvPvFrcVIdw', 2),
#  ('0KTwW1eC1YAjR-zDr8w4jA', 2),
#  ('0KaePrBSRJwUQaHywCM5Zw', 1),
#  ('0KlvdW9Jz6GAz967NHC9Pg', 2),
#  ('0Kn5W22UmxOqPj2cjouFNA', 1),
#  ('0KqHMwQIMUFys9rqlT3m2Q', 2),
#  ('0KwD4kiiIPoTOrHXVxwTyA', 1),
#  ('0L23LpzmR-kRsuIr9-zEXQ', 2),
#  ('0L5RXMLlh1AnzC-nu4oYQA', 1),
#  ('0LBWe0PB3rimYdcRKJCRdQ', 1),
#  ('0LLqluhzWOkz2H0GmSY_Sg', 3),
#  ('0LNbzt1dnlrqCAhNjK4SSA', 1),
#  ...]

# %%
from yelp_functions import sum_to_one
from tqdm.notebook import tqdm

restaurants_zip = restaurants_zip[:200]

# create empty list for restaurant vectors and price ratings
restaurants_vectors = []
restaurants_price = []

# create vectors for restaurants
for restaurant_id, price_range in tqdm(restaurants_zip):

    # set up the initial conditions
    r_vector = np.zeros(4096)
    temp_df = reviews[reviews['business_id'] == restaurant_id]
    bow_inputs = get_processed_inputs(temp_df[['text']])

    # get individual BoW representations
    bow_inputs = vectorizer.transform(bow_inputs)
    bow_inputs = bow_inputs.toarray()
    bow_inputs = sum_to_one(bow_inputs)

    # add up the individual BoW representations
    for vec in bow_inputs:
        r_vector += vec

    restaurants_vectors.append(r_vector)
    restaurants_price.append(price_range)

# check results for restaurants vectors
len(restaurants_vectors), restaurants_vectors[0].shape[0], restaurants_vectors[0].sum()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# (200, 4096, 14.0)

# %%
import pickle

ids = list(reviews.groupby('business_id').mean().index)

normalized_restaurants = sum_to_one(restaurants_vectors)
data_to_save = [ids, normalized_restaurants, restaurants_price]

with open("processed_data/restaurant_vectors", "wb") as pickle_file:
    pickle.dump(data_to_save, pickle_file)
