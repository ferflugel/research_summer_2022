# %%
import pandas as pd

# import data for businesses
businesses = pd.read_csv('csv_data/yelp_academic_dataset_business.csv')

# import data from states and sort it
states_data = pd.read_csv('processed_data/states_data.csv')
states_data = states_data.sort_values(by='gini_index_2019').reset_index(drop=True)

# add the level of inequality to states data
states_data['inequality'] = ''
states_data.loc[states_data.index < 17, 'inequality'] = 'low'
states_data.loc[states_data.index > 33, 'inequality'] = 'high'
states_data.loc[states_data['inequality'] == '', 'inequality'] = 'medium'

# check results
states_data
# Out:
#              state postal_code  gini_index_2019  gdppc_2021 inequality
# 0             Utah          UT           0.4268       66011        low
# 1            Idaho          ID           0.4337       49616        low
# 2          Wyoming          WY           0.4345       71911        low
# 3     South Dakota          SD           0.4360       68357        low
# 4           Alaska          AK           0.4376       75027        low
# 5        Wisconsin          WI           0.4391       62065        low
# 6           Hawaii          HI           0.4397       62474        low
# 7         Nebraska          NE           0.4400       76584        low
# 8    New Hampshire          NH           0.4406       70729        low
# 9             Iowa          IA           0.4422       68849        low
# 10       Minnesota          MN           0.4434       72187        low
# 11         Vermont          VT           0.4471       56028        low
# 12           Maine          ME           0.4490       55425        low
# 13          Kansas          KS           0.4500       65530        low
# 14          Oregon          OR           0.4500       62867        low
# 15        Delaware          DE           0.4509       80446        low
# 16        Colorado          CO           0.4548       72597        low
# 17    North Dakota          ND           0.4558       81795     medium
# 18        Maryland          MD           0.4558       71083     medium
# 19      Washington          WA           0.4577       86265     medium
# 20      Washington          WA           0.4577      226861     medium
# 21         Indiana          IN           0.4584       61760     medium
# 22         Arizona          AZ           0.4591       56511     medium
# 23         Montana          MT           0.4597       53703     medium
# 24    Rhode Island          RI           0.4628       60185     medium
# 25        Missouri          MO           0.4633       58356     medium
# 26        Michigan          MI           0.4634       56554     medium
# 27   West Virginia          WV           0.4644       49017     medium
# 28            Ohio          OH           0.4651       62517     medium
# 29        Virginia          VA           0.4690       68483     medium
# 30          Nevada          NV           0.4710       61375     medium
# 31        Oklahoma          OK           0.4739       51861     medium
# 32         Alabama          AL           0.4741       49027     medium
# 33  North Carolina          NC           0.4743       62077     medium
# 34    Pennsylvania          PA           0.4745       64751       high
# 35  South Carolina          SC           0.4747       52031       high
# 36       Tennessee          TN           0.4749       59969       high
# 37        Arkansas          AR           0.4750       47770       high
# 38           Texas          TX           0.4753       67235       high
# 39        Kentucky          KY           0.4764       52002       high
# 40      New Mexico          NM           0.4768       51481       high
# 41      New Jersey          NJ           0.4782       72524       high
# 42         Georgia          GA           0.4795       63271       high
# 43        Illinois          IL           0.4800       74052       high
# 44   Massachusetts          MA           0.4803       91129       high
# 45         Florida          FL           0.4808       56301       high
# 46      California          CA           0.4866       85546       high
# 47     Mississippi          MS           0.4896       42411       high
# 48       Louisiana          LA           0.4978       55213       high
# 49     Connecticut          CT           0.5024       82233       high
# 50        New York          NY           0.5149       93463       high

# %%
# add inequality level to each business
states_dict = dict(zip(states_data['postal_code'].tolist(), states_data['inequality'].tolist()))
businesses['state_inequality'] = businesses['state'].apply(lambda x: states_dict.get(x))

# check results
businesses
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2                  5255 E Broadway Blvd         Tucson    AZ       85711
# 3                           935 Race St   Philadelphia    PA       19107
# 4                         101 Walnut St     Green Lane    PA       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    AB     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    TN       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    IN       46250
# 150344                     2472 Troy Rd   Edwardsville    IL       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    FL       33572
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       34.426679 -119.711197    5.0             7        0
# 1       38.551126  -90.335695    3.0            15        1
# 2       32.223236 -110.880452    3.5            22        0
# 3       39.955505  -75.155564    4.0            80        1
# 4       40.338183  -75.471659    4.5            13        1
# ...           ...         ...    ...           ...      ...
# 150341  53.468419 -113.492054    3.0            13        1
# 150342  36.115118  -86.766925    4.0             5        1
# 150343  39.908707  -86.065088    3.5             8        1
# 150344  38.782351  -89.950558    4.0            24        1
# 150345  27.771002  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 1                  {'BusinessAcceptsCreditCards': 'True'}
# 2       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...                                                   ...
# 150341  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344  {'BusinessParking': "{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours state_inequality
# 0                                                     NaN             high
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...           medium
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...           medium
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...             high
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...             high
# ...                                                   ...              ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...             None
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...             high
# 150343                                                NaN           medium
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...             high
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...             high
#
# [150346 rows x 15 columns]

# %%
# create a dict to transfer the data
businesses_dict = dict(zip(businesses['business_id'].tolist(), businesses['state_inequality'].tolist()))

# import data for reviews and sample it
reviews = pd.read_csv('csv_data/yelp_academic_dataset_review.csv').sample(frac=0.1, random_state=0)

# add inequality levels for reviews
reviews['state_inequality'] = reviews['business_id'].apply(lambda x: businesses_dict.get(x))

# check results
reviews
# Out:
#                       review_id                 user_id  \
# 3014718  EXt74EO6JhK-2dM44f8KiA  JapJQZIsWLn8MpsHOH6J-w
# 6473116  xQ0skqjmT1o4o_QqbVjzeg  Q0Y7P42DgCjCN4gOHpL91Q
# 5966131  2ov0mIOaYUCanSxXiemjJQ  ryBRMyty7d2lxO19q_oPjg
# 2066348  Bv8gCzzR3gdacxeQ8ZrHgw  W1GvlnCar_UjOK3Go3iVYQ
# 112607   1d0l2nyTEDjrpwS3BV-ABQ  UTsHQia_JFcg1deWozrvXQ
# ...                         ...                     ...
# 4130384  bRBnGQtWV-giTCvl6RiuBQ  zZvlvWrWxka2Q0wEEgaYqA
# 1625675  8J_OD5dcVfcLV8RwnEwuMw  DuwZ_C3ZncPtEtTWeEPFjw
# 3262276  wZZSsUVFwlyMhTrRngtC-Q  TQ2PSzXAvLTjDheHP9S7lg
# 4601676  2V6jKH9KfSBJOgXT8b3ceA  TNLaYYt1Tpy4YqghZUvt1A
# 5055783  l8rkO2NYecKJtYI6NCLEvQ  n_N81qyY1EDcS_5weTpvyA
#
#                     business_id  stars  useful  funny  cool  \
# 3014718  ySHS6i9RxGZOIkVPcj-ckQ    3.0     0.0    0.0   0.0
# 6473116  Cbktlvci_z4HwdqPUW-5cg    3.0     0.0    0.0   0.0
# 5966131  hJTwBhYBTkiHaDMml_v_sw    1.0     2.0    0.0   0.0
# 2066348  mFWFtD6bXdpLz8bDXe-LHw    5.0     0.0    0.0   0.0
# 112607   6exYCuj4iSl1Hd6hb0C_Bg    5.0     0.0    0.0   1.0
# ...                         ...    ...     ...    ...   ...
# 4130384  CjotjEjteeBeBsURCPBZxQ    1.0     3.0    0.0   1.0
# 1625675  Vn6fOha6UZ2HGyZoAcxPkw    5.0     0.0    0.0   0.0
# 3262276  jz41zeEyGVEBhE2LiROICQ    1.0     1.0    0.0   0.0
# 4601676  WnyiCJfpsl1RViIWafNwIA    4.0     6.0    2.0   5.0
# 5055783  mIJ5w3UWJvYxKWNiNijVWw    5.0     0.0    0.0   0.0
#
#                                                       text  \
# 3014718  I had the 6 ounce Filet with the mixed vegetab...
# 6473116  Super friendly service. Fair price on drinks. ...
# 5966131  I swear you could order just a side baguette a...
# 2066348  Just WOW!  My friends know how much I'm a tea ...
# 112607   I gave Leigh Anne a photo that I found on the ...
# ...                                                    ...
# 4130384  I had a technician come out on 6/29 after my A...
# 1625675  BEST gophers and pralines ever. Seriously supe...
# 3262276  Tragic.  I used to visit Thai Nana when they w...
# 4601676  Think of how much you enjoy a fine adult bever...
# 5055783  I had a great experience at Hyundai of Wesley ...
#
#                         date state_inequality
# 3014718  2014-04-08 00:37:08           medium
# 6473116  2018-09-17 20:43:45             high
# 5966131  2018-11-06 19:47:46             high
# 2066348  2019-10-16 14:48:38             high
# 112607   2015-01-21 23:50:03           medium
# ...                      ...              ...
# 4130384  2019-07-03 16:45:48           medium
# 1625675  2018-03-10 01:07:39             high
# 3262276  2015-03-04 19:41:39             high
# 4601676  2009-12-29 21:18:16           medium
# 5055783  2014-10-25 16:10:58             high
#
# [699028 rows x 10 columns]

# %%
# use only reviews that have either high or low inequality
reviews = reviews[reviews['state_inequality'].isin(['high', 'low'])]

# reduce the dataset to 10000 reviews of each category
sampled_reviews = reviews.groupby('state_inequality').apply(lambda x: x.sample(10000, random_state=0).reset_index(drop=True))
sampled_reviews = sampled_reviews.droplevel(level=0)

# check results
sampled_reviews.groupby('state_inequality').count()
# Out:
#                   review_id  user_id  business_id  stars  useful  funny  \
# state_inequality
# high                  10000    10000        10000  10000   10000  10000
# low                   10000    10000        10000  10000   10000  10000
#
#                    cool   text   date
# state_inequality
# high              10000  10000  10000
# low               10000  10000  10000

# %%
# check mean rating for each group
sampled_reviews.groupby('state_inequality').mean()
# Out:
#                    stars  useful   funny    cool
# state_inequality
# high              3.7748  1.1527  0.3262  0.4669
# low               3.6695  1.1169  0.2583  0.3941

# %%
# check correlation between inequality and gdppc
states_data.corr()
# Out:
#                  gini_index_2019  gdppc_2021
# gini_index_2019         1.000000   -0.022353
# gdppc_2021             -0.022353    1.000000

# %%
from yelp_functions import get_processed_inputs, sum_to_one
from sklearn.feature_extraction.text import CountVectorizer

# use BoW to create vectors
bow_inputs = get_processed_inputs(sampled_reviews)

# create the BoW representation for the set
count_vec = CountVectorizer(max_features=1024, ngram_range=(1,2))
bow_representation = count_vec.fit_transform(bow_inputs)

# create the array with BoW and normalize it
bow_array = bow_representation.toarray()
bow_normalized = sum_to_one(bow_array)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

review_group = sampled_reviews['state_inequality'].tolist()
X_train, X_test, y_train, y_test = train_test_split(np.array(bow_normalized), np.array(review_group), test_size = 0.25, random_state=0)

# using KNNs for classification
knn = KNeighborsClassifier(n_neighbors=20).fit(X_train, y_train)
print("KNN test score:", knn.score(X_test, y_test))
print("KNN train score:", knn.score(X_train, y_train))

# using SVMs for classification
svm = SVC().fit(X_train, y_train)
print("SVM test score:", svm.score(X_test, y_test))
print("SVM train score:", svm.score(X_train, y_train))

# using random forests for classification
rfc = RandomForestClassifier(max_depth=6, random_state=0).fit(X_train, y_train)
print("RF test score:", rfc.score(X_test, y_test))
print("RF train score:", rfc.score(X_train, y_train))
# Out:
# KNN test score: 0.5444
# KNN train score: 0.6201333333333333
# SVM test score: 0.6134
# SVM train score: 0.8924666666666666
# RF test score: 0.613
# RF train score: 0.6877333333333333

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

# using logistic regression for classification
lrc = LogisticRegression(random_state=0).fit(X_train, y_train)
print("LR test score:", lrc.score(X_test, y_test))
print("LR train score:", lrc.score(X_train, y_train))

# using logistic regression for classification
nbc = MultinomialNB().fit(X_train, y_train)
print("NB test score:", nbc.score(X_test, y_test))
print("NB train score:", nbc.score(X_train, y_train))
# Out:
# LR test score: 0.6192
# LR train score: 0.6519333333333334
# NB test score: 0.6226
# NB train score: 0.6612

# %%
import gensim.downloader as api

# getting the pre-trained word2vec model
w2v = api.load('word2vec-google-news-300')

# %%
# we now test the model (just for demonstrations purposes)
vec_king = w2v['king']
w2v.similarity('king', 'queen')
# Out:
# 0.6510957

# %%
# create inputs for the w2v model
w2v_inputs = get_processed_inputs(sampled_reviews, mode='list_of_lists')
w2v_inputs
# Out:
# [['heard',
#   'place',
#   'donuts',
#   'philly',
#   '.',
#   'donuts',
#   'hot',
#   'fresh',
#   'lacked',
#   'flavor',
#   '.',
#   'chose',
#   'cookies',
#   'cream',
#   'raspberry',
#   ',',
#   'maybe',
#   'way',
#   'excited',
#   'eat',
#   ',',
#   'bit',
#   'disappointed',
#   '.',
#   'customer',
#   'service',
#   'good',
#   'coffee',
#   '.'],
#  ['ok',
#   ',',
#   'bestie',
#   'needed',
#   'drive',
#   ',',
#   'decided',
#   'drive',
#   'santa',
#   'barbara',
#   'los',
#   'angeles',
#   ',',
#   'minute',
#   'decision',
#   'arrived',
#   'santa',
#   'barbara',
#   '3',
#   'pm',
#   'hungry',
#   'breakfast',
#   ',',
#   'yelped',
#   'mexican',
#   'restaurant',
#   'dine',
#   'restaurant',
#   'closest',
#   ',',
#   'bestie',
#   'thought',
#   'place',
#   'authentic',
#   '/',
#   'mexican',
#   'good',
#   ',',
#   'like',
#   'american',
#   'mexican',
#   ',',
#   ',',
#   'went',
#   'low',
#   'expectations',
#   ',',
#   'bestie',
#   'asked',
#   'server',
#   'places',
#   '"',
#   'better',
#   '"',
#   'mexican',
#   'food',
#   ',',
#   'server',
#   'kept',
#   'insisting',
#   'beat',
#   'place',
#   ',',
#   'doubtful',
#   ',',
#   'said',
#   'order',
#   'drink',
#   'order',
#   'guacamole',
#   '.',
#   'surprise',
#   'food',
#   'good',
#   '!',
#   'great',
#   'quality',
#   'ingredients',
#   ',',
#   'dish',
#   'disappointed',
#   '!',
#   'humbled',
#   'amassed',
#   'experience',
#   '.',
#   'guacamole',
#   ',',
#   'order',
#   'steak',
#   'fajitas',
#   '.',
#   'came',
#   'hand',
#   'tortillas',
#   'ugh',
#   'good',
#   '!',
#   'definitely',
#   'coming',
#   '!',
#   '\n\n',
#   'btw',
#   ':',
#   'waiter',
#   'awesome',
#   '!'],
#  ['pretty',
#   'clean',
#   'neighborhood',
#   'bar',
#   '.',
#   'good',
#   'half',
#   'price',
#   'apps',
#   'like',
#   'enjoy',
#   'week',
#   'nights',
#   '.',
#   'bad',
#   'place',
#   'hang',
#   'buddies',
#   ',',
#   'college',
#   'night',
#   'fun',
#   '.',
#   '\n\n',
#   '5',
#   '-',
#   'star',
#   ',',
#   'think',
#   'staff',
#   ',',
#   'bowling',
#   'alley',
#   ',',
#   'food',
#   ',',
#   'beer',
#   'mellowness',
#   '4star',
#   'review',
#   '.'],
#  ['ate',
#   'times',
#   'day',
#   'stay',
#   'tampa',
#   '.',
#   'good',
#   'pho',
#   ',',
#   'happy',
#   'find',
#   'place',
#   '.',
#   'pho',
#   'dinner',
#   'twice',
#   ',',
#   'bun',
#   '(',
#   'noodle',
#   'bowl',
#   ')',
#   'buffet',
#   'style',
#   'lunch',
#   '.',
#   'definitely',
#   'prefer',
#   'dinner',
#   'service',
#   'buffet',
#   'lunch',
#   '(',
#   'reason',
#   'taking',
#   'star',
#   ')',
#   '.',
#   'lunch',
#   'fresh',
#   'dinner',
#   'meal',
#   '.',
#   '\n\n',
#   'summer',
#   'rolls',
#   'huge',
#   '.',
#   'saw',
#   'people',
#   'eating',
#   'meal',
#   'appetizer',
#   '.',
#   'pho',
#   '"',
#   'boats',
#   '"',
#   'large',
#   'contain',
#   'plenty',
#   'noodles',
#   'meat',
#   '.',
#   'broth',
#   'flavorful',
#   'delicate',
#   '.',
#   'wish',
#   'tripe',
#   'tendon',
#   'pho',
#   'dac',
#   'biet',
#   ',',
#   'ingredients',
#   ',',
#   'dish',
#   'satisfying',
#   '.',
#   'prices',
#   'reasonable',
#   '.',
#   'definitely',
#   'recommend',
#   'place',
#   'dinner',
#   'downtown',
#   'tampa',
#   'feel',
#   'like',
#   'having',
#   'pho',
#   '.'],
#  ['coming',
#   'sushi',
#   'probably',
#   'find',
#   '4',
#   'star',
#   '.',
#   'coming',
#   'group',
#   'getting',
#   'hot',
#   'meals',
#   'sushi',
#   'looking',
#   '3',
#   'stars',
#   '(',
#   'experience',
#   ')',
#   '.',
#   '\n\n',
#   'group',
#   '(',
#   '5',
#   'people',
#   ')',
#   'bring',
#   'food',
#   'wait',
#   'period',
#   'time',
#   'plates',
#   'come',
#   ',',
#   'plates',
#   'cold',
#   '.',
#   'group',
#   'better',
#   'time',
#   'come',
#   'time',
#   ',',
#   'especially',
#   'hot',
#   'ones.the',
#   'server',
#   'usually',
#   'kinda',
#   'slow',
#   'gives',
#   'attitude',
#   'need',
#   'split',
#   'check',
#   '.',
#   'trying',
#   'hot',
#   'lunch',
#   'plan',
#   'long',
#   'lunch',
#   '.',
#   '\n\n',
#   'price',
#   'sushi',
#   'great',
#   'food',
#   'like',
#   'green',
#   'curry',
#   'delicious',
#   '!',
#   'curry',
#   'dishes',
#   'mild',
#   'enjoy',
#   'ask',
#   'pepper',
#   'like',
#   'super',
#   'hot',
#   'like',
#   '.',
#   '\n\n',
#   'overall',
#   'ok',
#   'place',
#   ',',
#   'food',
#   'delicious',
#   'service',
#   'thing',
#   'hope',
#   'improve',
#   '.'],
#  ['friendly',
#   'staff',
#   ',',
#   'quick',
#   'service',
#   ',',
#   'great',
#   'sushi',
#   '!',
#   'dynamite',
#   'roll',
#   'mexican',
#   'roll',
#   'amazing',
#   '!',
#   'small',
#   'indoor',
#   'seating',
#   'area',
#   ',',
#   'outside',
#   'seating',
#   'available',
#   '.'],
#  ['dinner',
#   'giuseppe',
#   '&',
#   'sons',
#   'amazing',
#   '.',
#   'server',
#   ',',
#   'bennett',
#   ',',
#   'wonderfully',
#   'attentive',
#   'charming',
#   '.',
#   'tell',
#   'genuinely',
#   'cared',
#   'experience',
#   '.',
#   'price',
#   'point',
#   'vs',
#   'portion',
#   'sizes',
#   'generous',
#   'great',
#   'sharing',
#   '.',
#   'tastes',
#   'south',
#   'philly',
#   ',',
#   'ambiance',
#   '.',
#   'said',
#   'restaurant',
#   'places',
#   'tables',
#   'appropriate',
#   'distance',
#   'feel',
#   'like',
#   'conversation',
#   'shouting',
#   '.',
#   'plus',
#   'termini',
#   'cannolis',
#   '.',
#   'excited',
#   '!'],
#  ['casino',
#   '...',
#   'means',
#   'smoke',
#   ',',
#   'people',
#   'donating',
#   'money',
#   'entertainment',
#   'think',
#   'earning',
#   'income',
#   '.',
#   ' ',
#   'base',
#   'principles',
#   ',',
#   'pretty',
#   'nice',
#   'casino',
#   '.',
#   ' ',
#   'pretty',
#   'new',
#   '-',
#   'designed',
#   'recently',
#   '.',
#   ' ',
#   'lots',
#   'nice',
#   'bars',
#   'meeting',
#   'folks',
#   '.',
#   ' ',
#   'main',
#   'downside',
#   'smoke',
#   '-',
#   'nice',
#   'able',
#   'leave',
#   'bars',
#   'smell',
#   'like',
#   'ashtray',
#   '.',
#   ' ',
#   'casino',
#   'pretty',
#   'good',
#   'option',
#   '.'],
#  ['place',
#   'recommended',
#   'local',
#   'met',
#   'bar',
#   '.',
#   'looking',
#   'late',
#   'night',
#   'eats',
#   '.',
#   'atmosphere',
#   'divey',
#   ',',
#   'burgers',
#   'good',
#   '!',
#   'especially',
#   'price',
#   '.',
#   'going',
#   'ambience',
#   'fit',
#   'bill',
#   'perfectly',
#   '.',
#   'cheap',
#   ',',
#   'fast',
#   'tasty',
#   '!',
#   '!'],
#  ['delicious',
#   '!',
#   '!',
#   '!',
#   'favorite',
#   'places',
#   'nashville',
#   '!',
#   'happy',
#   'opening',
#   'second',
#   'location',
#   'west',
#   'nashville',
#   '!',
#   'try',
#   'place',
#   '!',
#   'worth',
#   '!'],
#  ['cut',
#   'large',
#   'trees',
#   'backyard',
#   '.',
#   ' ',
#   'excellent',
#   'job',
#   '!',
#   ' ',
#   'received',
#   'recommendation',
#   'neighbor',
#   'wanted',
#   'pass',
#   'good',
#   'experience',
#   '.'],
#  ['came',
#   'home',
#   'long',
#   'day',
#   'working',
#   '7',
#   '9',
#   'pm',
#   '.',
#   'looking',
#   'forward',
#   'red',
#   'beans',
#   'rice',
#   '.',
#   'fam',
#   'got',
#   'order',
#   'red',
#   'beans',
#   'rice',
#   'sausage',
#   '.',
#   'open',
#   'plate',
#   ',',
#   'looks',
#   'like',
#   'vomit',
#   '.',
#   'smell',
#   'rancid',
#   '.',
#   'trash',
#   'plate',
#   '.',
#   'sure',
#   'long',
#   'ago',
#   'cook',
#   'red',
#   'beans',
#   '.',
#   'place',
#   'trash',
#   '.'],
#  ['definitely',
#   'huge',
#   'fan',
#   'goodwill',
#   '.',
#   'comparison',
#   ',',
#   ' ',
#   'expensive',
#   '.',
#   'mean',
#   'like',
#   '$',
#   '15',
#   'pair',
#   'kmart',
#   'jeans',
#   '.',
#   ' ',
#   'things',
#   'pay',
#   'things',
#   'wo',
#   '.',
#   ' ',
#   'prices',
#   ',',
#   'buy',
#   'new',
#   'clothes',
#   '.',
#   ' ',
#   'customer',
#   'service',
#   'great',
#   '.',
#   ' ',
#   'super',
#   'long',
#   'lines',
#   ',',
#   'associates',
#   'probably',
#   'work',
#   'disorganized',
#   'racks',
#   'clothes',
#   '.',
#   ' ',
#   'said',
#   ',',
#   ' ',
#   'goodwill',
#   'stores',
#   'brighter',
#   ',',
#   'better',
#   'selections',
#   'merchandise',
#   'happier',
#   'associates',
#   '.'],
#  ['zero',
#   '!',
#   '!',
#   'took',
#   'bag',
#   'brand',
#   'new',
#   'carhart',
#   'jeans',
#   'dickies',
#   '.',
#   'paid',
#   '.',
#   'brought',
#   '2',
#   'bags',
#   'oz',
#   'husbands',
#   'carhart',
#   'shorts',
#   'tees',
#   'northface',
#   'tees',
#   'shorts',
#   '.',
#   'bags',
#   'packed',
#   '.',
#   'went',
#   'pick',
#   'tod',
#   'want',
#   'bags',
#   'stained',
#   'and/or',
#   'faded',
#   '.',
#   'husbanfd',
#   'wear',
#   'stain',
#   '.',
#   'mean',
#   'fault',
#   'perfectionist',
#   '.',
#   'wasted',
#   'time',
#   'know',
#   'rejected',
#   'husbands',
#   'clothes',
#   '.',
#   'shame',
#   '!',
#   'girl',
#   'counter',
#   'stomach',
#   'hanging',
#   'vixen',
#   'tattoo',
#   '.',
#   'believe',
#   'manager',
#   '!',
#   ' ',
#   'poor',
#   'business',
#   'attire',
#   '.....'],
#  ['service',
#   'bit',
#   'slow',
#   ',',
#   'menu',
#   'packed',
#   'things',
#   'going',
#   'try',
#   '.',
#   'mom',
#   'enjoyed',
#   'cocktail',
#   'options',
#   ',',
#   'mentioned',
#   'drinks',
#   'bit',
#   'weak',
#   '.',
#   'loved',
#   'avacado',
#   'toast',
#   '...',
#   'small',
#   'plates',
#   'small',
#   '.',
#   'overall',
#   ',',
#   'recommend',
#   'place',
#   'plan',
#   ',',
#   'hoping',
#   'faster',
#   'service',
#   'better',
#   'quality',
#   'drinks',
#   'future',
#   '.'],
#  ['looking',
#   'authentic',
#   'northern',
#   'vietnamese',
#   'cusine',
#   ',',
#   'look',
#   ' ',
#   '!',
#   'thang',
#   'long',
#   'place',
#   '!',
#   'bun',
#   'ch',
#   'ha',
#   'ni',
#   ',',
#   'ph',
#   'ga',
#   ',',
#   'bun',
#   'mang',
#   'vt',
#   'nt',
#   'forget',
#   'order',
#   'steamed',
#   'chicken',
#   'table',
#   'share',
#   '!',
#   ',',
#   'bun',
#   'ch',
#   'ha',
#   'ni',
#   '!',
#   'honestly',
#   'nt',
#   'think',
#   'find',
#   'authentic',
#   'bun',
#   'ch',
#   'apart',
#   'thang',
#   'long',
#   'philly',
#   ':)'],
#  ['ordered',
#   'thai',
#   'hot',
#   '.',
#   '  ',
#   'eggplant',
#   'dish',
#   '.',
#   '  ',
#   'actually',
#   'bitter',
#   'taste',
#   '.',
#   '  ',
#   'think',
#   'forgot',
#   'ingredients',
#   '.',
#   ' ',
#   'chicken',
#   'tough',
#   '.',
#   ' ',
#   'disappointing',
#   '.',
#   ' ',
#   'took',
#   '35',
#   'min',
#   '.',
#   ' ',
#   'care',
#   'food',
#   'delish',
#   '.',
#   '  ',
#   'potstickers',
#   'good',
#   '.'],
#  ['food',
#   'poisoning',
#   ':',
#   'eat',
#   '.',
#   'purchased',
#   'general',
#   'tso',
#   'chicken',
#   'brown',
#   'rice',
#   'lunch',
#   'special',
#   '.',
#   'cheap',
#   ',',
#   'chicken',
#   'undercooked',
#   'rice',
#   'old',
#   '.',
#   'wonton',
#   'soup',
#   'nasty',
#   '.',
#   'sure',
#   'thing',
#   'ate',
#   ',',
#   'combination',
#   ',',
#   '100',
#   '%',
#   'sure',
#   'new',
#   'imperial',
#   'chinese',
#   'resturant',
#   'gave',
#   'food',
#   'poisoning',
#   '.',
#   'pain',
#   'worth',
#   'price',
#   '.'],
#  ['husband',
#   'love',
#   'restaurant',
#   ',',
#   'eat',
#   '2',
#   '-',
#   '3',
#   'month',
#   'enjoy',
#   'single',
#   'time',
#   '.',
#   'wait',
#   'staff',
#   'wonderful',
#   'food',
#   'consistently',
#   'good',
#   '.'],
#  ['usual',
#   'stops',
#   'shopping',
#   'south',
#   'street',
#   '.',
#   'jewelry',
#   'selection',
#   'amazing',
#   '!',
#   'trip',
#   'times',
#   'year',
#   'purchase',
#   'different',
#   'pieces',
#   ',',
#   'pricey',
#   ',',
#   'worth',
#   'opinion',
#   '.',
#   'tons',
#   'compliments',
#   'things',
#   '.',
#   'staff',
#   'super',
#   'friendly',
#   'helpful',
#   '.',
#   'overall',
#   'great',
#   'experience',
#   '.',
#   'bonus',
#   ':',
#   'lion',
#   'statue',
#   'shop',
#   'favorite',
#   'parts',
#   'south',
#   'street',
#   '.',
#   'pat',
#   'head',
#   'luck',
#   ',',
#   'lol',
#   '!'],
#  ['wanted',
#   'love',
#   '.',
#   'nice',
#   'bar',
#   'good',
#   'crowd',
#   '.',
#   'food',
#   'ok',
#   '.',
#   'tried',
#   'things',
#   'far',
#   'best',
#   'things',
#   'eggplant',
#   'rollatini',
#   ',',
#   'garlic',
#   'knots',
#   ',',
#   'sausage',
#   'onions',
#   'peppers',
#   'pasta',
#   'carbonara',
#   '.',
#   'crab',
#   'risotto',
#   'horrible',
#   '...',
#   'crab',
#   'spoiled',
#   'smell',
#   'soon',
#   'came',
#   '.',
#   'chef',
#   'caught',
#   '.',
#   'ordered',
#   'dirty',
#   'martini',
#   'bartender',
#   'obviously',
#   'loaded',
#   'vermouth',
#   'admit',
#   '.',
#   'undrinkable',
#   '.',
#   'personally',
#   'trip',
#   'villaggio',
#   'lutz',
#   'better',
#   'food',
#   '.'],
#  ['great',
#   'food',
#   'seasoned',
#   '.',
#   'food',
#   'comes',
#   'hot',
#   'fast',
#   '.',
#   'recommend',
#   'fried',
#   'fish',
#   'fried',
#   'pickles',
#   '.',
#   'sauce',
#   'delicious',
#   '.'],
#  ['love',
#   'chic',
#   'fil',
#   ',',
#   'people',
#   'work',
#   'amazing',
#   '.',
#   'met',
#   'great',
#   'people',
#   'crossing',
#   'community',
#   'church',
#   'face',
#   'painting',
#   'ordered',
#   'food',
#   'kids',
#   '.',
#   'time',
#   'ordered',
#   'food',
#   'family',
#   'realized',
#   'grab',
#   'wallet',
#   '.',
#   'manager',
#   'register',
#   'told',
#   'ok',
#   'worries',
#   ',',
#   'house',
#   '.',
#   'shocked',
#   'told',
#   'pay',
#   'morning',
#   '.',
#   'insisted',
#   'ok',
#   '!',
#   'love',
#   'gets',
#   'busy',
#   'extra',
#   'time',
#   'spent',
#   'line',
#   'gets',
#   'fresh',
#   'hot',
#   'chicken',
#   '.'],
#  ['bike',
#   'tour',
#   'fantastic',
#   'way',
#   'french',
#   'quarter',
#   'district',
#   '!',
#   'went',
#   'fabulous',
#   'time',
#   '!',
#   'teddy',
#   'extremely',
#   'knowledgable',
#   'city',
#   '&',
#   'fun',
#   'entertaining',
#   '!',
#   'bikes',
#   'new',
#   'comfortable',
#   'cruisers',
#   '.',
#   'husband',
#   'avid',
#   'cyclist',
#   'experienced',
#   ',',
#   'loved',
#   '!',
#   'teddy',
#   '&',
#   'ryan',
#   'wonderful',
#   'deal',
#   'helpful',
#   '.',
#   'highly',
#   'recommend',
#   'tour',
#   '!'],
#  ['setting',
#   '2',
#   'stars',
#   '.',
#   'fresh',
#   'sushi',
#   'great',
#   'atmosphere',
#   '.',
#   'dined',
#   'multiple',
#   'times',
#   'gotten',
#   'multiple',
#   'times',
#   '.',
#   ',',
#   ' ',
#   'reviewing',
#   'overall',
#   'experience',
#   '.',
#   'experience',
#   'experience',
#   '.',
#   'ordered',
#   'sushi',
#   '-',
#   'thing',
#   'order',
#   'hair',
#   'sushi',
#   '.',
#   ' ',
#   'thing',
#   'concerns',
#   ',',
#   'called',
#   'tell',
#   'restaurant',
#   'discovered',
#   'food',
#   'thought',
#   'disturbing',
#   ',',
#   'chuckled',
#   'joke',
#   '.',
#   'asked',
#   'hold',
#   'speak',
#   'manager',
#   ',',
#   'ask',
#   'like',
#   'remade',
#   ',',
#   'act',
#   'sympathetic',
#   'way',
#   '.',
#   'spent',
#   '$',
#   '70',
#   'sushi',
#   'thrown',
#   'away',
#   '.',
#   'bad',
#   'business',
#   '.'],
#  ['like',
#   'hanging',
#   'bars',
#   'frenchmen--',
#   'way',
#   'crowded',
#   'yuki',
#   'exception',
#   '.',
#   'times',
#   ',',
#   'packed',
#   ',',
#   'usually',
#   'avoid',
#   '.',
#   'spent',
#   'hours',
#   '-',
#   'night',
#   'lovely',
#   '.',
#   'good',
#   'selection',
#   'japanese',
#   'beers',
#   ',',
#   'high',
#   'ceilings',
#   ',',
#   'awesome',
#   'decor',
#   '(',
#   'imperial',
#   'japanese',
#   'flag',
#   'wtf',
#   ')',
#   '.',
#   'great',
#   'live',
#   'music',
#   '.',
#   '\n\n',
#   'serve',
#   'wide',
#   'variety',
#   'japanese',
#   'dishes',
#   '.',
#   'unfortunately',
#   ',',
#   'good',
#   '.',
#   'ramen',
#   'tasted',
#   'like',
#   'jazzed',
#   'maruchan',
#   ',',
#   'gyoza',
#   'flavorless',
#   '.',
#   'recommend',
#   'house',
#   'plum',
#   'wine',
#   '.'],
#  ['amazing',
#   'server',
#   '\n',
#   'amazing',
#   'wine',
#   'list',
#   '\n',
#   'best',
#   'steak',
#   '.',
#   'sure',
#   'tour',
#   'wine',
#   'cellar',
#   'presidential',
#   'seating',
#   'area',
#   '.'],
#  ['.',
#   ' \n\n',
#   'elderly',
#   'african',
#   'american',
#   'waitress',
#   'hands',
#   'rudest',
#   'server',
#   '(',
#   'heck',
#   ',',
#   'rudest',
#   'individuals',
#   ')',
#   'encountered',
#   '.',
#   ' ',
#   'took',
#   '10',
#   'mins',
#   'greet',
#   '(',
#   'dining',
#   'room',
#   'weekday',
#   'morning',
#   '11:30',
#   ')',
#   'water',
#   ',',
#   'menus',
#   '&',
#   'coffee',
#   ',',
#   'longer',
#   'bring',
#   'water',
#   '3',
#   'worst',
#   'bloodies',
#   'collectively',
#   'tasted',
#   ',',
#   'mocked',
#   'laughing',
#   'private',
#   'conversation',
#   '(',
#   'approached',
#   'table',
#   'cackling',
#   'loudly',
#   '&',
#   'flailing',
#   'hands',
#   ')',
#   ',',
#   'told',
#   '"',
#   'stop',
#   'playing',
#   'toys',
#   '"',
#   'hands',
#   '(',
#   'cellphones',
#   '-',
#   "ma'am",
#   ',',
#   'tourists',
#   'french',
#   'quarter',
#   'taking',
#   'time',
#   'map',
#   'day',
#   'sit',
#   'hot',
#   '-',
#   'minute',
#   ')',
#   ',',
#   'fun',
#   'friend',
#   'mispronouncing',
#   'menu',
#   ',',
#   'took',
#   'sweet',
#   'time',
#   'bringing',
#   'bill',
#   'dining',
#   'room',
#   'table',
#   'long',
#   'cleared',
#   '(',
#   'took',
#   ')',
#   '.',
#   ' ',
#   'god',
#   'forbid',
#   'asked',
#   'extra',
#   'plate',
#   '(',
#   '"',
#   'ya',
#   'got',
#   'right',
#   '"',
#   'said',
#   ',',
#   'pointing',
#   'tiny',
#   ',',
#   'gumbo',
#   '-',
#   'covered',
#   'plate',
#   'cup',
#   'gumbo',
#   'served',
#   '-',
#   'joking',
#   ',',
#   '*',
#   '*',
#   'bring',
#   ')',
#   'refill',
#   'napkin',
#   '...',
#   'worst',
#   '.',
#   ' \n\n',
#   'hoping',
#   'food',
#   'amazing',
#   'ms',
#   '.',
#   'crabby',
#   '-',
#   'pants',
#   ',',
#   '.',
#   ' ',
#   'mediocre',
#   '.',
#   ' ',
#   '3',
#   'hungry',
#   'gals',
#   'took',
#   'late',
#   'flight',
#   'nola',
#   'night',
#   'starving',
#   'walked',
#   'door',
#   'finish',
#   'plates',
#   '.',
#   '\n\n',
#   'instead',
#   'offended',
#   ',',
#   'absolutely',
#   'stunned',
#   '.',
#   ' ',
#   'drunk',
#   ',',
#   'obnoxious',
#   '-',
#   '.',
#   ' ',
#   'hungry',
#   ',',
#   'paying',
#   'customers',
#   '/',
#   'tourists',
#   'excited',
#   'try',
#   'new',
#   'place',
#   '.',
#   ' \n\n',
#   "ma'am",
#   ',',
#   'come',
#   ',',
#   'respect',
#   'elders',
#   'polite',
#   ',',
#   'minded',
#   'manners',
#   'fair',
#   'tip',
#   ',',
#   'embarrassed',
#   'way',
#   'treated',
#   '.',
#   ' ',
#   'nice',
#   'day',
#   '.'],
#  ['chain',
#   'act',
#   '.',
#   ' ',
#   'food',
#   'good',
#   'great',
#   'customer',
#   'service',
#   'fast',
#   'food',
#   'chain',
#   '.',
#   ' ',
#   'clean',
#   'looking',
#   'polite',
#   'employees',
#   '.'],
#  ['appointment',
#   'online',
#   'emma',
#   'owner',
#   'responded',
#   'quickly',
#   '.',
#   'went',
#   'accommodating',
#   '.',
#   'judy',
#   'amazing',
#   '!',
#   'told',
#   'wanted',
#   'exactly',
#   'wanted',
#   '.',
#   'mermaid',
#   'nails',
#   ' ',
#   'amazing',
#   '.',
#   'definitely'],
#  ['love',
#   'going',
#   'craft',
#   'beer',
#   'cellar',
#   '!',
#   'exactly',
#   'familiar',
#   'beers',
#   'pat',
#   'knowledge',
#   'share',
#   'find',
#   'happy',
#   '.',
#   'love',
#   'brewery',
#   'come',
#   'tasting',
#   '.',
#   'nice',
#   'opportunities',
#   'try',
#   'new',
#   '.',
#   'craft',
#   'beer',
#   'cellar',
#   'great',
#   'stop',
#   'going',
#   'outing',
#   '.'],
#  ['ok',
#   'mexican',
#   'chain',
#   '(',
#   'upscale',
#   ')',
#   'tampa',
#   'mall',
#   '.',
#   'iron',
#   'skillet',
#   'tacos',
#   '(',
#   'fajita',
#   ')',
#   'pork',
#   'al',
#   'pastor',
#   'good',
#   '.',
#   'queso',
#   'fundido',
#   'appetizer',
#   '.',
#   'house',
#   'special',
#   'margarita',
#   '(',
#   'tasted',
#   'like',
#   'sangria',
#   ')',
#   '.',
#   'portions',
#   'huge',
#   'room',
#   'dessert',
#   ',',
#   'check',
#   'comes',
#   'churros',
#   '.',
#   '3',
#   'stars',
#   '?',
#   'tampa',
#   'great',
#   'mexican',
#   'places',
#   ',',
#   'ok',
#   ',',
#   'higher',
#   'prices',
#   '.'],
#  ['came',
#   'restaurant',
#   'late',
#   'lunch',
#   'week',
#   'thanksgiving',
#   '.',
#   'visiting',
#   'town',
#   ',',
#   'coming',
#   'home',
#   'tampa',
#   'visit',
#   ',',
#   'wanted',
#   'taste',
#   'home',
#   'town',
#   'cuban',
#   'food',
#   '.',
#   'got',
#   '!',
#   'ordered',
#   'way',
#   'sat',
#   'grazing',
#   ',',
#   'thoroughly',
#   'enjoying',
#   'experience',
#   '.',
#   ' ',
#   'nice',
#   'welcome',
#   'home',
#   'meal',
#   '!'],
#  ['food',
#   'ok',
#   '.',
#   'service',
#   'awful',
#   '.',
#   ' ',
#   ',',
#   '.',
#   'time',
#   'reopening',
#   '.',
#   'tonight',
#   'service',
#   'horrible',
#   'return',
#   '.',
#   ' ',
#   'shame',
#   'business',
#   'suffer',
#   'awful',
#   'server',
#   ',',
#   'care',
#   'apologize',
#   'told',
#   '.'],
#  ['extremely',
#   'happy',
#   'place',
#   'near',
#   '.',
#   'allowed',
#   'brewery',
#   ',',
#   'loading',
#   'dock',
#   ',',
#   'main',
#   'bar',
#   'seating',
#   'activities',
#   'place',
#   '.',
#   'dogs',
#   'families',
#   'welcome',
#   'bring',
#   'place',
#   'multiple',
#   'times',
#   'week',
#   'nice',
#   'long',
#   'walk',
#   '.',
#   '\n\n',
#   'good',
#   'stuff',
#   '!',
#   'beers',
#   'awesome',
#   ';',
#   'balanced',
#   'clean',
#   '.',
#   'flight',
#   'test',
#   'self',
#   '.',
#   'ipas',
#   'like',
#   'coho',
#   'hail',
#   'mary',
#   'taste',
#   'good',
#   'normally',
#   'like',
#   'style',
#   '.',
#   'overly',
#   'bitter',
#   'prefer',
#   '.',
#   'normally',
#   '6',
#   '-',
#   '8',
#   'beers',
#   'tap',
#   'breweries',
#   'cider',
#   'fruit',
#   'beer',
#   'option',
#   '.',
#   '\n\n',
#   'food',
#   'trucks',
#   'rotating',
#   'schedule',
#   'allowed',
#   'bring',
#   'food',
#   '.',
#   'wissahickon',
#   'brew',
#   'co.',
#   'philadelphia',
#   'penn',
#   'state',
#   'football',
#   'fan',
#   ',',
#   'game',
#   'large',
#   'projector',
#   '.'],
#  ['like',
#   'mazzaro',
#   'saint',
#   'pete',
#   ',',
#   'love',
#   'la',
#   'casa',
#   'del',
#   'pane',
#   '.',
#   'exceptional',
#   'bread',
#   'pastries',
#   'nice',
#   'small',
#   'simple',
#   'menu',
#   'breakfast',
#   'sandwiches',
#   'entrees',
#   '.',
#   'nice',
#   'assortment',
#   'wines',
#   'groceries',
#   '.'],
#  ['ride',
#   'septa',
#   'hang',
#   'septic',
#   'tank',
#   ',',
#   '.',
#   '\n\n',
#   'station',
#   'directly',
#   'pops',
#   'water',
#   'ice',
#   'heart',
#   'old',
#   'south',
#   'philly',
#   '.',
#   'pretty',
#   'safe',
#   'time',
#   'careful',
#   ',',
#   'especially',
#   'late',
#   'night',
#   '.',
#   '\n\n',
#   'going',
#   '2',
#   'stars',
#   ',',
#   'ex',
#   '-',
#   'seption',
#   '3',
#   '.'],
#  ['wowwwwww',
#   '!',
#   'waiting',
#   'come',
#   'year',
#   '.',
#   'got',
#   '.',
#   'sitch',
#   ':',
#   'mimosas',
#   'bomb&boozy',
#   'af',
#   '!',
#   'atmosphere',
#   'perfect',
#   'wake',
#   'horrid',
#   'night',
#   'drinking',
#   '.',
#   'literally',
#   'notice',
#   'excuse',
#   'barf',
#   '.',
#   'busy',
#   '.',
#   'waitress',
#   'kind',
#   'understanding',
#   'date',
#   'particularly',
#   'like',
#   'dish',
#   '.',
#   'took',
#   'bill',
#   'asking',
#   '.',
#   'chicken',
#   'livers',
#   'worth',
#   'tend',
#   'eat',
#   'organ',
#   'meats',
#   '!',
#   'taste',
#   'like',
#   'chicken',
#   '!',
#   '!',
#   '!',
#   'mean',
#   ',',
#   'pepper',
#   'jelly',
#   'die',
#   '.',
#   'added',
#   'new',
#   'orleans',
#   'flair',
#   ',',
#   'ask',
#   'extra',
#   'green',
#   'onions',
#   '.',
#   ' ',
#   'date',
#   'enjoy',
#   'meal',
#   'boudin',
#   ',',
#   'special',
#   ',',
#   'tried',
#   'good',
#   '.',
#   'boudin',
#   'come',
#   'casing',
#   'think',
#   'changed',
#   'perception',
#   'flavor',
#   'profile',
#   '.',
#   '(',
#   'boudin',
#   'typically',
#   'served',
#   'boiled',
#   'casing',
#   'fried',
#   'think',
#   'patty',
#   '.',
#   ')',
#   'tasted',
#   ',',
#   'taste',
#   'similarly',
#   'traditional',
#   'bad',
#   '.',
#   'plate',
#   'eggs',
#   'florentine',
#   'absolutely',
#   'perfect',
#   '.',
#   'change',
#   'eggs',
#   'runnier',
#   '.',
#   'word',
#   '?',
#   'lol',
#   'enjoy',
#   'bone',
#   'apple',
#   'tee'],
#  ['nicole',
#   'wonderful',
#   '!',
#   'fast',
#   'great',
#   'service',
#   '.',
#   '12',
#   'pm',
#   'appointment',
#   'took',
#   'right',
#   'away',
#   '.',
#   'regular',
#   'manicure',
#   '$',
#   '12',
#   'great',
#   'price',
#   '!'],
#  ['quality',
#   'good',
#   'west',
#   'chester',
#   '.',
#   ' ',
#   'price',
#   'great',
#   'quality',
#   'quantity',
#   '.',
#   ' ',
#   'people',
#   'like',
#   ',',
#   'find',
#   'bit',
#   'noisy',
#   '.',
#   ' ',
#   'big',
#   'plus',
#   ',',
#   'plenty',
#   'parking',
#   '!',
#   '\n\n',
#   'update',
#   ':',
#   '\n',
#   'got',
#   '.',
#   ' ',
#   'ask',
#   'fork',
#   'knife',
#   '.',
#   ' ',
#   'girl',
#   'told',
#   '"',
#   'provide',
#   '"',
#   '.',
#   ' ',
#   'accidentally',
#   'look',
#   'disbelieved',
#   'cause',
#   'told',
#   ',',
#   'provide',
#   '.',
#   ' ',
#   'ask',
#   'goto',
#   'store',
#   'ask',
#   '.',
#   ' ',
#   '?',
#   '\n\n',
#   'update',
#   ':',
#   '\n',
#   'finally',
#   'fix',
#   'problem',
#   '.',
#   ' ',
#   'time',
#   'order',
#   ',',
#   'girl',
#   'pleasantly',
#   'told',
#   'utensils',
#   'bag',
#   '.',
#   ' ',
#   'respect',
#   'addressing',
#   'issue',
#   'feedback',
#   '.'],
#  ['great',
#   'pizza',
#   ',',
#   'great',
#   'sandwiches',
#   ',',
#   'great',
#   'service',
#   'great',
#   'lunch',
#   'specials',
#   '.',
#   ' ',
#   'fresh',
#   ',',
#   'rolls',
#   'great',
#   'sandwiches',
#   'huge',
#   '.',
#   ' ',
#   'lunch',
#   'specials',
#   'extremely',
#   'reasonably',
#   'priced',
#   'come',
#   'basket',
#   'fries',
#   '(',
#   'awesome',
#   ')',
#   'soda',
#   '.',
#   ' ',
#   'delivery',
#   'service',
#   'prompt',
#   'want',
#   'food',
#   'delivered',
#   '.',
#   ' ',
#   'best',
#   'pizza',
#   'shop',
#   'willow',
#   'grove',
#   'area',
#   ',',
#   'far',
#   '.'],
#  ['wow',
#   '!',
#   ' ',
#   'places',
#   'nashville',
#   'food',
#   'scene',
#   'struggle',
#   'find',
#   'places',
#   'overpriced',
#   'tourist',
#   'trap',
#   '.',
#   ' ',
#   'place',
#   'great',
#   '.',
#   ' ',
#   'menu',
#   'smaller',
#   'ok',
#   'food',
#   'quality',
#   'good',
#   '.',
#   ' ',
#   'schnitzel',
#   'chart',
#   '.',
#   ' ',
#   'apps',
#   'shared',
#   'beef',
#   'tartar',
#   'pretzel',
#   'awesome',
#   '.',
#   ' ',
#   'server',
#   'scott',
#   'brought',
#   'homemade',
#   'bread',
#   '.',
#   ' ',
#   'mean',
#   'northeast',
#   'know',
#   'bread',
#   'nashville',
#   'sucks',
#   '!',
#   ' ',
#   'know',
#   ',',
#   'bread',
#   'amazing',
#   '!',
#   ' ',
#   'definitely',
#   '.',
#   ' ',
#   'interior',
#   'decor',
#   'cool',
#   '.',
#   ' ',
#   'way',
#   ',',
#   'biggest',
#   'pet',
#   'peeve',
#   'restaurants',
#   'slam',
#   'people',
#   'table',
#   ',',
#   'charge',
#   'nose',
#   'expect',
#   'pleasant',
#   'dining',
#   'experience',
#   '.',
#   ' ',
#   'makeready',
#   '!',
#   ' ',
#   'seating',
#   'areas',
#   'spacious',
#   'elbow',
#   'room',
#   '.'],
#  ['like',
#   'update',
#   'review',
#   'restaurant',
#   '!',
#   ' ',
#   'e',
#   'mailed',
#   'shock',
#   'price',
#   'increase',
#   'specials',
#   'friends',
#   'ordered',
#   '.',
#   '30minutes',
#   'received',
#   'response',
#   'george',
#   '.',
#   'offered',
#   'heartfelt',
#   'apology',
#   'gift',
#   'card',
#   ',',
#   ' ',
#   'hopes',
#   'come',
#   'shot',
#   ',',
#   '.',
#   ' ',
#   'hear',
#   'amazing',
#   'lunch',
#   'buffet',
#   '.',
#   'received',
#   'gift',
#   'card',
#   'mail',
#   'immediately',
#   ',',
#   'george',
#   'promised',
#   '.',
#   'feeling',
#   'likely',
#   'accurate',
#   'representation',
#   'customer',
#   'service',
#   ',',
#   'initial',
#   'experience',
#   'anomaly',
#   '.'],
#  ['extremely',
#   'rude',
#   'horrible',
#   'customer',
#   'service',
#   '.',
#   'talked',
#   'like',
#   'unimportant',
#   '.',
#   'definitely',
#   'wo',
#   'coming',
#   '.',
#   'good',
#   'impression',
#   '.'],
#  ['favorite',
#   'restaurants',
#   '.',
#   'dining',
#   'experience',
#   'class',
#   'ralphs',
#   '.',
#   'facility',
#   'unique',
#   '.',
#   'love',
#   'location',
#   '.',
#   'food',
#   'service',
#   'notch',
#   '.',
#   'prices',
#   'fair',
#   '.',
#   'feel',
#   'gouged',
#   '.',
#   'recommend',
#   'ralph',
#   'time',
#   '.',
#   'easy',
#   'park',
#   'come',
#   '.',
#   ':)'],
#  ['2',
#   'surgeries',
#   'dr',
#   'moreno',
#   '.',
#   'second',
#   'rear',
#   'ended',
#   'kid',
#   'texting',
#   '.',
#   'dr',
#   'moreno',
#   'quick',
#   'suggest',
#   'surgery',
#   '.',
#   'tried',
#   'conservative',
#   'route',
#   'decided',
#   'surgery',
#   'getting',
#   'better',
#   '.',
#   'knowledgeable',
#   'great',
#   'bedside',
#   'manner',
#   '.',
#   'physical',
#   'therapist',
#   'st',
#   'joe',
#   'told',
#   'patients',
#   '.',
#   ' ',
#   'recommend',
#   '.'],
#  ['hype',
#   '?',
#   'went',
#   'night',
#   'couple',
#   'left',
#   'disappointed',
#   '.',
#   'starters',
#   'ok',
#   'sushi',
#   'impressive',
#   '.',
#   'wife',
#   'tuna',
#   'guac',
#   'start',
#   '.',
#   'tuna',
#   'guac',
#   'soy',
#   'sauce',
#   'drizzle',
#   '.',
#   'interesting',
#   'sauce',
#   '.',
#   'ok',
#   '.',
#   'grilled',
#   'ribs',
#   'ton',
#   'toro',
#   '(',
#   'pig',
#   'jowls',
#   ')',
#   'nice',
#   'smoky',
#   'flavor',
#   '.',
#   'best',
#   'apps',
#   'chasu',
#   'buns',
#   'pretty',
#   'bao',
#   'buns',
#   '.',
#   'nice',
#   'flavors',
#   'texture',
#   '.',
#   'sushi',
#   '.',
#   ',',
#   'left',
#   'bites',
#   'sushi',
#   'donated',
#   'waste',
#   'bin',
#   ',',
#   'finish',
#   'spider',
#   'roll',
#   '.',
#   'soft',
#   'shell',
#   'crab',
#   'encased',
#   'bland',
#   ',',
#   'crusty',
#   'panko',
#   '.',
#   'rolls',
#   'meh',
#   '.',
#   '(',
#   'big',
#   'mouths',
#   ')',
#   '.',
#   'points',
#   'beer',
#   'list',
#   'sake',
#   '.',
#   'went',
#   'high',
#   'expectations',
#   '.',
#   'left',
#   'looking',
#   'place',
#   'eat',
#   '.'],
#  ['stairs',
#   'fine',
#   ',',
#   'good',
#   'price',
#   '.',
#   ' ',
#   'sales',
#   'person',
#   'courteous',
#   ',',
#   'gave',
#   'contractor',
#   'incorrect',
#   'way',
#   'measure',
#   ',',
#   'stairs',
#   'short',
#   '.',
#   ' ',
#   'build',
#   'wooden',
#   'stairs',
#   'work',
#   '.',
#   ' ',
#   'alternative',
#   'pay',
#   'large',
#   'price',
#   'metal',
#   'stairs',
#   'plus',
#   'shipping',
#   '.',
#   ' ',
#   'needed',
#   'add',
#   'additional',
#   'reinforcing',
#   'bolts',
#   'sturdy',
#   '.',
#   ' ',
#   'understand',
#   'salesman',
#   'longer',
#   'company',
#   ',',
#   'safe',
#   '.',
#   ' ',
#   'aware',
#   'good',
#   ',',
#   'economical',
#   'stairway',
#   'system',
#   ',',
#   'need',
#   'modify',
#   'best',
#   'results',
#   '.'],
#  ['everybody',
#   'dunkin',
#   "'",
#   'donuts',
#   '1',
#   'million',
#   'times',
#   'find',
#   'nicer',
#   'people',
#   'find',
#   '.',
#   'store',
#   'spotlessly',
#   'clean',
#   'incredibly',
#   'efficient',
#   'time',
#   '.',
#   'importantly',
#   ',',
#   'nicest',
#   'food',
#   'service',
#   'employees',
#   'encounter',
#   '.'],
#  ['trying',
#   'adopt',
#   'greyson',
#   'year',
#   '.',
#   'got',
#   'response',
#   '\n ',
#   'cage',
#   'got',
#   'fat',
#   '.',
#   'fat',
#   'unhealthy',
#   'cat',
#   '.',
#   'sure',
#   'got',
#   'bad',
#   'arthritis',
#   '.',
#   'applied',
#   'got',
#   '.',
#   'called',
#   'said',
#   'talk',
#   'people',
#   'taking',
#   'applications',
#   '.',
#   'march',
#   '2021',
#   '.',
#   'calls',
#   '.',
#   ' ',
#   'cat',
#   'held',
#   'hostage',
#   '?',
#   'want',
#   'adopt',
#   'cares',
#   '!',
#   'called',
#   '.',
#   'tried',
#   'tried',
#   'adopt',
#   'cares',
#   '.',
#   '  ',
#   'want',
#   'let',
#   'cat',
#   'rot',
#   'cage',
#   '$',
#   '300',
#   '.',
#   'going',
#   'vet',
#   '.',
#   '$',
#   '50',
#   'dollar',
#   'old',
#   'cat',
#   '.',
#   'maybe',
#   '$',
#   '100',
#   'chance',
#   'life',
#   '.',
#   ' ',
#   'need',
#   'sued',
#   '.',
#   'giving',
#   'pets',
#   'chance',
#   '.',
#   'year',
#   'cage',
#   '.',
#   'different',
#   'slavery',
#   '?',
#   'cruel',
#   '.',
#   'know',
#   'handle',
#   '.',
#   'needs',
#   'come',
#   'home',
#   'live',
#   'peace',
#   'comfortable',
#   'surroundings',
#   '..',
#   'sad',
#   '.',
#   'damaged',
#   'prostituted',
#   'cat',
#   '.',
#   '$',
#   '300-',
#   'god',
#   'intervene.i',
#   'want',
#   'cat',
#   ',',
#   '?',
#   'asked',
#   'times',
#   '.',
#   'cat',
#   'adoptable',
#   '.',
#   'answer',
#   'application',
#   'etc',
#   '.',
#   'year',
#   ',',
#   'let',
#   '!'],
#  ['loved',
#   'salt',
#   'pepper',
#   '.',
#   'think',
#   'favorite',
#   'restaurant',
#   ',',
#   'owing',
#   'scallop',
#   'appetizer',
#   'menu',
#   '(',
#   'delicious',
#   ')',
#   ',',
#   'chicken',
#   'risotto',
#   'dish',
#   ',',
#   'homemade',
#   ',',
#   'comfort',
#   'desserts',
#   '(',
#   'e.g.',
#   ',',
#   'apple',
#   'pie',
#   ')',
#   'regularly',
#   'offered',
#   '.',
#   'learned',
#   'salt',
#   'pepper',
#   ',',
#   'disappointed',
#   '.',
#   'naturally',
#   ',',
#   'sophia',
#   'opened',
#   ',',
#   'anxious',
#   'replaced',
#   '-',
#   'place',
#   '.',
#   'tried',
#   'week',
#   'new',
#   'opening',
#   'food',
#   'ok',
#   '.',
#   'figured',
#   'dealing',
#   'growing',
#   'pains',
#   'things',
#   'better',
#   '.',
#   'went',
#   ',',
#   'appetizers',
#   '(',
#   'meatballs',
#   'polenta',
#   ')',
#   'delicious',
#   ',',
#   'found',
#   'entree',
#   'exciting',
#   '.',
#   'tried',
#   'time',
#   '.',
#   'apps',
#   'good',
#   'entree',
#   '.',
#   'ordered',
#   'chicken',
#   'spinach',
#   'fontina',
#   'cheese',
#   'dish',
#   '(',
#   'think',
#   'menu',
#   ')',
#   'inedible',
#   '.',
#   'husband',
#   'pork',
#   'cheek',
#   'ok',
#   '.',
#   'liked',
#   'salt',
#   'pepper',
#   'offered',
#   'upscale',
#   'comfort',
#   'food',
#   '.',
#   'like',
#   'lot',
#   'folks',
#   'prefer',
#   'new',
#   ',',
#   'fancier',
#   ',',
#   'genre',
#   'food',
#   '.',
#   ',',
#   '.',
#   '\n\n',
#   'maybe',
#   'try',
#   'later',
#   'menu',
#   'changes',
#   ',',
#   ',',
#   'rush',
#   'head',
#   '.',
#   'said',
#   ',',
#   'waitstaff',
#   'great',
#   '.'],
#  ['originally',
#   'chose',
#   'motel',
#   'post',
#   'card',
#   'inn',
#   'booked',
#   ',',
#   'retrospect',
#   ',',
#   'glad',
#   '!',
#   '\n\n',
#   'place',
#   'turned',
#   'total',
#   'gem',
#   '.',
#   'luckily',
#   ',',
#   'popped',
#   'early',
#   'check',
#   ',',
#   'good',
#   'office',
#   'open',
#   'day',
#   '/',
#   'night',
#   'like',
#   'hotels',
#   '.',
#   'got',
#   'real',
#   'mom',
#   '-',
#   '-',
#   'pop',
#   'feel',
#   '.',
#   '\n\n',
#   'revamped',
#   '/',
#   'modernized',
#   'old',
#   'dolphin',
#   'motel',
#   'keeping',
#   'retro',
#   'charm',
#   '.',
#   'happy',
#   'grounds',
#   ',',
#   'pools',
#   '(',
#   'yeah',
#   ',',
#   'tiny',
#   'property',
#   ')',
#   ',',
#   'room',
#   'awesome',
#   'amenities',
#   'like',
#   'free',
#   'bike',
#   'rental',
#   ',',
#   'free',
#   'beach',
#   'wagon',
#   'rental',
#   ',',
#   'lawn',
#   'games',
#   '.',
#   '\n\n',
#   'room',
#   'featured',
#   'memory',
#   'foam',
#   'king',
#   'sized',
#   'bed',
#   '(',
#   'little',
#   'soft',
#   ',',
#   'personal',
#   'preference',
#   ')',
#   ',',
#   'bathroom',
#   'filled',
#   '-',
#   '-',
#   'marble',
#   ',',
#   'large',
#   'flat',
#   'screen',
#   ',',
#   'kitchenette',
#   '...',
#   'pretty',
#   'need',
#   'vacay',
#   '.',
#   '\n\n',
#   'oh',
#   ',',
#   'mention',
#   'like',
#   '30',
#   '-',
#   'second',
#   'walk',
#   'beach',
#   '?',
#   '\n\n',
#   'safety',
#   'tip',
#   ':',
#   'locked',
#   'door',
#   'walk',
#   'away',
#   '(',
#   'paranoid',
#   'self',
#   ')',
#   'jiggled',
#   'handle',
#   'noticed',
#   'lock',
#   'properly',
#   '.',
#   'sure',
#   'double',
#   'check',
#   'older',
#   'building',
#   'quirks',
#   '.'],
#  ['small',
#   'plates',
#   'good',
#   'love',
#   'atmosphere',
#   '.',
#   'sitting',
#   'looking',
#   'town',
#   '&',
#   'playhouse',
#   'large',
#   'windows',
#   'beautiful',
#   'day',
#   'night',
#   '.',
#   'gets',
#   'crowded',
#   'weekends',
#   '!',
#   '\n\n',
#   'whiskey',
#   '/',
#   'wine',
#   'bar',
#   ',',
#   'wish',
#   'options',
#   'additional',
#   'cocktails',
#   '.',
#   'whiskey',
#   'drinker',
#   'like',
#   'vodka',
#   '/',
#   'gin',
#   '/',
#   'tequila',
#   'cocktail',
#   '.',
#   'wish',
#   'gf',
#   'options',
#   '!',
#   'overall',
#   ',',
#   'food',
#   'wine',
#   'enjoyed',
#   '.',
#   'fun',
#   'place',
#   'small',
#   'group',
#   'chill',
#   'night',
#   'date',
#   'night',
#   '.'],
#  ['visited',
#   'place',
#   'times',
#   '.',
#   'great',
#   'food',
#   'good',
#   'prices',
#   '.',
#   'visit',
#   'sure',
#   '.',
#   'normally',
#   'oxtail',
#   'dinner',
#   '.'],
#  ['husband',
#   'shopping',
#   'ipad',
#   'helped',
#   'julia',
#   '.',
#   'wonderful',
#   ',',
#   'knowledgeable',
#   ',',
#   'patient',
#   'kind',
#   'encouraging',
#   '!',
#   'wait',
#   'help',
#   ',',
#   'customers',
#   'store',
#   '.',
#   'highly',
#   'recommend',
#   'store',
#   'julia',
#   '!'],
#  ['nice',
#   'little',
#   'hole',
#   'wall',
#   'restaurant',
#   '.',
#   'stay',
#   'treasure',
#   'island',
#   'brunch',
#   'dinner',
#   '.',
#   'staff',
#   'knowledgeable',
#   'food',
#   'menu',
#   'huge',
#   'plus',
#   'deciding',
#   'wanted',
#   'eat',
#   '.',
#   'dinner',
#   'got',
#   'blackened',
#   'sea',
#   'bass',
#   'sadly',
#   'cooked',
#   'lightly',
#   'fluffy',
#   'expected',
#   '.',
#   'got',
#   'shrimp',
#   'bisque',
#   'wow',
#   'blew',
#   'park',
#   '!',
#   'definitely',
#   'suggest',
#   'shrimp',
#   'bisque',
#   'appetizer',
#   '!',
#   'dish',
#   'got',
#   'jambalaya',
#   'incredible',
#   ',',
#   'definitely',
#   'try',
#   'item',
#   '.',
#   'brunch',
#   'good',
#   ',',
#   'got',
#   'seafood',
#   'benny',
#   'cajun',
#   'benny',
#   'delightful',
#   ',',
#   'good',
#   'size',
#   'good',
#   'price',
#   '!',
#   'soon',
#   '!'],
#  ['stopped',
#   'weekend',
#   'best',
#   'times',
#   'family',
#   '.',
#   'farm',
#   'apple',
#   'picking',
#   ',',
#   'pumpkin',
#   'picking',
#   ',',
#   'corn',
#   'fields',
#   'sunflower',
#   'fields',
#   '.',
#   'shop',
#   'farm',
#   ',',
#   'food',
#   'stands',
#   ',',
#   'animal',
#   'farm',
#   'winery',
#   '.',
#   '\n\n',
#   'loved',
#   'apple',
#   'picking',
#   '.',
#   'trees',
#   'unlike',
#   'seen',
#   '.',
#   'tall',
#   'filed',
#   'delicious',
#   'apples',
#   '.',
#   'got',
#   'half',
#   'bag',
#   '$',
#   '9',
#   '.',
#   'told',
#   'fill',
#   'way',
#   'shy',
#   '.',
#   'sweet',
#   '.',
#   '\n\n',
#   'took',
#   'wonderful',
#   'pictures',
#   'sunflower',
#   'field',
#   '.',
#   'purchase',
#   'flowers',
#   ',',
#   'passed',
#   '.',
#   'interested',
#   'seeds',
#   '.',
#   'flowers',
#   'developed',
#   'eaten',
#   '.',
#   '\n\n',
#   'store',
#   'great',
#   '.',
#   'wonderful',
#   'fall',
#   'decor',
#   '.',
#   'grabbed',
#   'vase',
#   'house',
#   '.',
#   'local',
#   'honey',
#   ',',
#   'apple',
#   'cider',
#   'donuts',
#   '(',
#   'heavenly',
#   ')',
#   ',',
#   'beautiful',
#   'scented',
#   'soaps',
#   '!',
#   '\n\n',
#   'food',
#   'stand',
#   'great',
#   'food',
#   '.',
#   'pulled',
#   'pork',
#   'nachos',
#   'favorite',
#   '.',
#   'hotdog',
#   'delicious',
#   '.',
#   '\n\n',
#   'reservations',
#   'wine',
#   'tasting',
#   'ahead',
#   'time',
#   '.',
#   'glad',
#   '.',
#   'sold',
#   'day',
#   '.',
#   'choice',
#   'wines',
#   '$',
#   '8',
#   '.',
#   'total',
#   'steal',
#   '.',
#   'wine',
#   'okay',
#   '.',
#   'halloween',
#   'brew',
#   'favorite',
#   '.',
#   'grabbed',
#   'bottles',
#   '.',
#   'served',
#   'cold',
#   'hot',
#   'caught',
#   'interest',
#   '.',
#   'great',
#   'spicy',
#   'kick',
#   '.',
#   'overpowering',
#   '.',
#   'sadly',
#   ',',
#   'favorite',
#   ',',
#   'cabernet',
#   'tasteful',
#   '.',
#   'hard',
#   'apple',
#   'ciders',
#   'good',
#   '.',
#   'overall',
#   'tasting',
#   'cost',
#   '.',
#   '\n\n',
#   'live',
#   'band',
#   'playing',
#   'enjoyed',
#   '.',
#   'hall',
#   'wedding',
#   '.',
#   'got',
#   'wedding',
#   'going',
#   'looked',
#   'absolutely',
#   'breathtaking',
#   '.',
#   '\n\n',
#   'family',
#   'enjoyed',
#   'trip',
#   '.',
#   'definitely',
#   'come',
#   'fall',
#   '!'],
#  ['thought',
#   'entire',
#   'life',
#   'write',
#   'negative',
#   'review',
#   'chick',
#   '-',
#   'fil',
#   '-',
#   ',',
#   '.',
#   'wait',
#   '40',
#   '-',
#   'minute',
#   'drive',
#   '-',
#   'line',
#   'order',
#   'avoid',
#   'krizian',
#   ',',
#   'cashier',
#   'inside',
#   '.',
#   'rudest',
#   'cashier',
#   'experienced',
#   'chick',
#   '-',
#   'fil',
#   '-',
#   'a.',
#   'interaction',
#   'started',
#   'miserably',
#   'aggressive',
#   'fact',
#   'tell',
#   'order',
#   '-',
#   '.',
#   'kept',
#   'tirade',
#   'continued',
#   'order',
#   '.',
#   'instead',
#   'answering',
#   'questions',
#   ',',
#   'passive',
#   '-',
#   'aggressively',
#   'told',
#   'look',
#   'menu',
#   'board',
#   '.',
#   'messed',
#   'payment',
#   'like',
#   'fault',
#   'misunderstanding',
#   '.',
#   'restaurant',
#   'notoriously',
#   'known',
#   'overkill',
#   'kindness',
#   ',',
#   'left',
#   'feeling',
#   'belittled',
#   'frustrated',
#   'service',
#   'received',
#   '.',
#   'surprised',
#   'keeping',
#   '.'],
#  ['rodizio',
#   'grill',
#   'voorhees',
#   'great',
#   'date',
#   'night',
#   '.',
#   'phenomenal',
#   'salad',
#   'bar',
#   'filled',
#   'veggies',
#   ',',
#   'fruits',
#   'sides',
#   '.',
#   'eaten',
#   ',',
#   'flip',
#   'card',
#   'table',
#   'green',
#   'begin',
#   'eating',
#   'finished',
#   'need',
#   'flip',
#   'red',
#   '.',
#   'green',
#   'shows',
#   'ready',
#   'servers',
#   'come',
#   'fresh',
#   'meat',
#   'red',
#   'shows',
#   'taking',
#   'break',
#   'finished',
#   'meal',
#   '.',
#   'highly',
#   'suggest',
#   'buying',
#   'bottle',
#   'wine',
#   'table',
#   '.',
#   'wines',
#   'pair',
#   'nice',
#   'steaks',
#   'serve',
#   '.',
#   ':-)',
#   'great',
#   'atmosphere',
#   '!',
#   'sure',
#   'hungry',
#   '!'],
#  ['enjoyed',
#   'evening',
#   '.',
#   'server',
#   'friendly',
#   'helpful',
#   ',',
#   'food',
#   'terrific',
#   'wine',
#   'great',
#   '.',
#   'awesome',
#   'place',
#   'great',
#   'turkish',
#   'food',
#   'coffee'],
#  ['enjoyed',
#   'restaurant',
#   '.',
#   'quaint',
#   'cozy',
#   '.',
#   'service',
#   'bit',
#   'long',
#   'weekends',
#   'reservations',
#   'food',
#   'worth',
#   'wait',
#   '.',
#   'chicken',
#   'sandwich',
#   'comes',
#   'fries',
#   'pickle',
#   '.',
#   'chicken',
#   'fantastic',
#   'crunch',
#   'light',
#   'cooked',
#   '.',
#   'ordered',
#   'iced',
#   'coffee',
#   ',',
#   'disappointed',
#   '.',
#   'fan',
#   'coffee',
#   'service',
#   '.',
#   'place',
#   'byob',
#   'wanting',
#   'good',
#   'drink',
#   'eat',
#   ',',
#   'bring',
#   '!',
#   'stop',
#   'grab',
#   'bite',
#   ',',
#   'wo',
#   'regret',
#   '.'],
#  ['came',
#   'friend',
#   'redeem',
#   'groupons',
#   'rosemary',
#   'arnica',
#   'masssages',
#   '.',
#   ' ',
#   'friend',
#   'spa',
#   'trying',
#   'great',
#   'experience',
#   '.',
#   ' ',
#   'big',
#   'mistake',
#   'start',
#   '.',
#   '\n\n',
#   ',',
#   'left',
#   'waiting',
#   'room',
#   'minutes',
#   'past',
#   'appointment',
#   'time',
#   '.',
#   ' ',
#   'waiting',
#   'room',
#   'spa',
#   '-',
#   'like',
#   '.',
#   ' ',
#   'brightly',
#   'lit',
#   'glass',
#   'window',
#   'faces',
#   'pool',
#   'open',
#   'hotel',
#   'guests',
#   ',',
#   'alittle',
#   'awkward',
#   '.',
#   ' ',
#   'water',
#   'tea',
#   'light',
#   'snacks',
#   'like',
#   'seen',
#   'higher',
#   'end',
#   'spas',
#   '.',
#   ' \n\n',
#   'massage',
#   'terrible',
#   '.',
#   ' ',
#   'great',
#   '.',
#   ' ',
#   'noticed',
#   'therapist',
#   'left',
#   'room',
#   ' ',
#   'turned',
#   'clock',
#   'face',
#   'wall',
#   '.',
#   ' ',
#   'weird',
#   ' ',
#   'turned',
#   'look',
#   '.',
#   ' ',
#   'ended',
#   'early',
#   'original',
#   'treatment',
#   'time',
#   ',',
#   'let',
#   'minute',
#   'wait',
#   '!',
#   ' ',
#   'figure',
#   'got',
#   'cut',
#   'short',
#   '20',
#   'minutes',
#   ',',
#   'probably',
#   '.',
#   ' ',
#   'friend',
#   'probably',
#   'got',
#   'half',
#   'time',
#   'paid',
#   '.',
#   ' \n\n',
#   'thought',
#   'poor',
#   'treatment',
#   'groupon',
#   'reading',
#   'reviews',
#   'standard',
#   '.',
#   ' ',
#   'definitely',
#   'going',
#   'changes',
#   'management',
#   'place',
#   '.'],
#  ['came',
#   'moxie',
#   'intention',
#   'having',
#   'healthy',
#   'breakfast',
#   '.',
#   ' ',
#   ',',
#   'standing',
#   'large',
#   'menu',
#   'board',
#   'staring',
#   'cuban',
#   'sandwich',
#   '.',
#   ' ',
#   'days',
#   'cuban',
#   ',',
#   'curiosity',
#   'got',
#   'best',
#   '.',
#   ' ',
#   'understand',
#   ',',
#   'curiosity',
#   'got',
#   'cat',
#   'lot',
#   'trouble',
#   '.',
#   ' ',
#   'killed',
#   'actually',
#   '.',
#   ' \n\n',
#   ',',
#   'staring',
#   'cuban',
#   '.',
#   ' ',
#   'breakfast',
#   'nonetheless',
#   '.',
#   ' ',
#   'best',
#   'ham',
#   'salami',
#   'sandwiches',
#   '.',
#   ' ',
#   'pork',
#   '.',
#   ' ',
#   'guessing',
#   ',',
#   '.',
#   '  ',
#   'thoroughly',
#   'enjoyed',
#   'sandwich',
#   'nonetheless',
#   '.',
#   '\n\n',
#   'meal',
#   'added',
#   'potato',
#   'salad',
#   'soft',
#   'drink',
#   '(',
#   'yes',
#   ',',
#   'breakfast',
#   ')',
#   '.',
#   'potato',
#   'salad',
#   'skipped',
#   '.',
#   ' ',
#   'bland',
#   'flavor',
#   '.',
#   '\n\n',
#   'wife',
#   'egg',
#   'white',
#   'veggie',
#   'omelette',
#   'tomatoes',
#   '.',
#   ' ',
#   'look',
#   'picture',
#   '!',
#   ' ',
#   'wow',
#   '!',
#   ' ',
#   'beautiful',
#   'tasted',
#   'great',
#   '.',
#   ' \n\n',
#   'menu',
#   'peanut',
#   'butter',
#   'jelly',
#   'sandwiches',
#   '.',
#   ' ',
#   'interesting',
#   '.',
#   ' ',
#   'breakfast',
#   'sandwich',
#   'combinations',
#   'cuban',
#   'bread',
#   'nice',
#   '.',
#   ' ',
#   ' ',
#   'nice',
#   'selection',
#   'sandwiches',
#   ',',
#   'coffees',
#   ',',
#   'smoothies',
#   '.',
#   ' ',
#   'makes',
#   'wish',
#   'stomachs',
#   '.',
#   '\n\n',
#   'definitely',
#   'declaring',
#   'fan',
#   'place',
#   '.',
#   ' ',
#   'folks',
#   'friendly',
#   ',',
#   'ate',
#   'good',
#   '(',
#   'albeit',
#   'worthy',
#   'best',
#   'cubans',
#   'list',
#   ',',
#   'good',
#   'nonetheless',
#   ')',
#   ',',
#   'price',
#   'reasonable',
#   '.',
#   ' ',
#   'definitely',
#   'coming',
#   'recommend',
#   'place',
#   'highly',
#   '.'],
#  ['best',
#   'best',
#   '!',
#   'going',
#   '2014',
#   'refuse',
#   '!',
#   'waxing',
#   ',',
#   'eyebrow',
#   'threading',
#   'facials',
#   '!',
#   'worth',
#   'drive',
#   'time',
#   '.'],
#  ['spicy',
#   'boudin',
#   'omelette',
#   'good',
#   '.',
#   'lots',
#   'boudin',
#   'stuffed',
#   '.',
#   'staff',
#   'great',
#   '.',
#   'negative',
#   '"',
#   'hash',
#   '"',
#   'came',
#   'unseasoned',
#   'frozen',
#   'hash',
#   'browns',
#   'toast',
#   'blah',
#   '.'],
#  ['stopped',
#   'lunch',
#   'friend',
#   '.',
#   'town',
#   'elephant',
#   'bar',
#   'disappointed',
#   'home',
#   ',',
#   'like',
#   'good',
#   'option',
#   '.',
#   '\n\n',
#   'sat',
#   'bar',
#   'area',
#   'service',
#   'slow',
#   '...',
#   'server',
#   'nicole',
#   'came',
#   'friendly',
#   'smile',
#   'greeted',
#   'noticed',
#   'helped',
#   '.',
#   ' ',
#   ',',
#   'prompt',
#   'helpful',
#   '.',
#   ' \n\n',
#   'split',
#   'calamari',
#   'spring',
#   'rolls',
#   'start',
#   '(',
#   'good',
#   ')',
#   ',',
#   'ginger',
#   'shrimp',
#   'noodles',
#   'love',
#   '.',
#   'friend',
#   'tried',
#   'new',
#   'entree',
#   'fried',
#   'rice',
#   '...',
#   'forgot',
#   'exactly',
#   'called',
#   'looked',
#   'good',
#   '.',
#   ' ',
#   'try',
#   'time',
#   '!',
#   '\n\n',
#   'overall',
#   ',',
#   'good',
#   'experience-',
#   'good',
#   'food',
#   'great',
#   'service',
#   '!'],
#  ['find',
#   'place',
#   '-',
#   'small',
#   'strip',
#   'center',
#   ',',
#   'happy',
#   'finally',
#   'u',
#   '-',
#   'turn',
#   'found',
#   '.',
#   'fresh',
#   'delicious',
#   'food',
#   ',',
#   'fabulous',
#   'reasonably',
#   'priced',
#   'cocktails',
#   '-',
#   'mango',
#   'habanero',
#   'margarita',
#   'delicious',
#   '!',
#   'chicken',
#   'tacos',
#   'hubs',
#   'chimichangas',
#   '.',
#   'salsa',
#   'homemade',
#   'spicy',
#   '!',
#   'chips',
#   'fresh',
#   'cooked',
#   '.',
#   'reasonably',
#   'priced',
#   ',',
#   'fantastic',
#   'service',
#   '!',
#   'definitely',
#   'return',
#   '!'],
#  ['average',
#   '.',
#   'breakfast',
#   'burger',
#   'good',
#   ',',
#   'patty',
#   'burnt',
#   'ends',
#   '.',
#   'cheese',
#   'fries',
#   'decent',
#   '.',
#   'wife',
#   'liked',
#   'burger',
#   'shake',
#   'ok',
#   '.',
#   'shake',
#   'originally',
#   'wanted',
#   ',',
#   'crispy',
#   'cream',
#   ',',
#   'got',
#   'heath',
#   'bar',
#   '.',
#   '\n\n',
#   'service',
#   'fine',
#   ',',
#   'ladies',
#   'friendly',
#   'helpful',
#   '.',
#   'food',
#   'come',
#   ',',
#   'busy',
#   '.',
#   '\n\n',
#   'decent',
#   'place',
#   'want',
#   'quiet',
#   'place',
#   'burger',
#   'shake',
#   'better',
#   'options',
#   ',',
#   'albeit',
#   'louder',
#   '.',
#   'continue',
#   'dine',
#   ',',
#   'expectations',
#   'high',
#   '.'],
#  ['spending',
#   'week',
#   'tampa',
#   'area',
#   '.',
#   'looked',
#   'reasonably',
#   'rated',
#   'restaurant',
#   'found',
#   'mystic',
#   'fish',
#   '.',
#   '\n',
#   'ambiance',
#   'nice',
#   '.',
#   'let',
#   'strip',
#   'mall',
#   'location',
#   'fool',
#   '-',
#   'inside',
#   'nicely',
#   'decorated',
#   'like',
#   'fine',
#   'seafood',
#   'restaurant',
#   '.',
#   ' ',
#   'space',
#   'large',
#   'split',
#   'sound',
#   'wall',
#   'aquariums',
#   'middle',
#   'ceiling',
#   'design',
#   'cut',
#   'nose',
#   'reasonable',
#   'level',
#   'busy',
#   'night',
#   '.',
#   '\n\n',
#   'spinach',
#   'salad',
#   ' ',
#   'bargain',
#   '.',
#   '  ',
#   'shrimp',
#   'scallops',
#   'linguini',
#   ' ',
#   'white',
#   'wine',
#   'butter',
#   'sauce',
#   'good',
#   'better',
#   'butter',
#   'little',
#   'lemon',
#   '.',
#   ' ',
#   'tasty',
#   ',',
#   'presented',
#   'ample',
#   'portion',
#   '.',
#   'good',
#   'value',
#   '.',
#   ' ',
#   'come',
#   'try',
#   'different',
#   '.',
#   '\n\n',
#   'lastly',
#   'great',
#   'service',
#   'service',
#   'staff',
#   'professional',
#   'friendly',
#   'professionally',
#   'dressed'],
#  ['family',
#   'went',
#   'yesterday',
#   'watch',
#   'usa',
#   'women',
#   'world',
#   'cup',
#   'game',
#   '.',
#   'called',
#   'sure',
#   'playing',
#   'game',
#   'big',
#   'tv',
#   '3:00',
#   '.',
#   'showed',
#   'right',
#   'start',
#   'game',
#   'disappointment',
#   'nbc',
#   'sports',
#   'arena',
#   'closed',
#   'maintenance',
#   '.',
#   'sat',
#   '1100',
#   'social',
#   'area',
#   '.',
#   'good',
#   'tvs',
#   '.',
#   'nice',
#   'waitress',
#   'took',
#   'drink',
#   'appetizers',
#   'orders',
#   'informed',
#   'arena',
#   'area',
#   '3:30',
#   '.',
#   'appreciative',
#   'excited',
#   'came',
#   'big',
#   'tv',
#   '.',
#   'soon',
#   'saw',
#   'waitress',
#   'disciplined',
#   'manager',
#   'waitress',
#   'soon',
#   'came',
#   ' ',
#   'told',
#   'needed',
#   'close',
#   'bill',
#   'moved',
#   'apology',
#   '.',
#   'waitress',
#   'inconveniencing',
#   'glad',
#   'moved',
#   '.',
#   'moved',
#   'arena',
#   'witnessed',
#   'manager',
#   'harassing',
#   'waitress',
#   'waiter',
#   '.',
#   'place',
#   'getting',
#   'crowded',
#   'baseball',
#   'fans',
#   'prior',
#   'game',
#   '.',
#   'waitress',
#   'came',
#   'apologized',
#   'longer',
#   'wait',
#   'demoted',
#   'drink',
#   '/',
#   'food',
#   'runner',
#   '.',
#   'happen',
#   'addressed',
#   'shift',
#   'manager',
#   '.',
#   'punishing',
#   'waitress',
#   'waiter',
#   'crowded',
#   'time',
#   ' ',
#   'affects',
#   'customers',
#   'service',
#   '.',
#   'felt',
#   'sorry',
#   'waitress',
#   'waiter',
#   'publicly',
#   'disciplined',
#   'obviously',
#   'managers',
#   'fault',
#   'scheduling',
#   'right',
#   'staff',
#   '.',
#   'food',
#   'good',
#   ',',
#   'manger',
#   'rude',
#   'disrespectful',
#   'staff',
#   '.',
#   '\n\n',
#   ',',
#   'union',
#   'flag',
#   'hung',
#   'philadelphia',
#   'spirts',
#   'teams',
#   '!',
#   'disappointing',
#   '.'],
#  ['great',
#   'experience',
#   'deluxe',
#   '!',
#   'love',
#   'fact',
#   'late',
#   'hours',
#   'convenient',
#   '!',
#   'nails',
#   '!',
#   'second',
#   'time',
#   'wait',
#   'long',
#   'pretty',
#   'quickly',
#   '.'],
#  ['yelp',
#   'led',
#   'excellent',
#   'restaurant',
#   '.',
#   'night',
#   'enjoyed',
#   'good',
#   'dinner',
#   '.',
#   '\n',
#   'started',
#   'best',
#   ':',
#   'appetizer',
#   'called',
#   'affettati',
#   'misti',
#   '.',
#   'arrives',
#   'wooden',
#   'plank',
#   'filled',
#   'chef',
#   'selection',
#   ' ',
#   'cheeses',
#   ',',
#   'meats',
#   ',',
#   'sweets',
#   ',',
#   'items',
#   'olives',
#   '.',
#   ' ',
#   'puffy',
#   'bread',
#   '-',
#   'cracker',
#   'served',
#   'base',
#   'eating',
#   '.',
#   ' ',
#   'thoroughly',
#   'enjoyed',
#   'item',
#   'platter',
#   '.',
#   ' ',
#   'calabrese',
#   'pizza',
#   ',',
#   'good',
#   'crust',
#   'little',
#   'doughy',
#   'taste',
#   '.',
#   ' ',
#   'husband',
#   'rigatoni',
#   'labels',
#   'good',
#   '.',
#   '\n',
#   'affettati',
#   'misti',
#   'expensive',
#   'worth',
#   'penny',
#   ';',
#   'pass',
#   '.',
#   '\n',
#   'labeled',
#   'noise',
#   'level',
#   'average',
#   ';',
#   'found',
#   'loud',
#   '.'],
#  ['menu',
#   'better',
#   'food',
#   '.',
#   'high',
#   'hopes',
#   '.',
#   'brisket',
#   'good',
#   'moist',
#   'flavorful',
#   '.',
#   'appy',
#   'queso',
#   'liquid',
#   'lacked',
#   'spice',
#   'chorizo',
#   'flavor',
#   'came',
#   '..',
#   'beans',
#   'thing',
#   'hot',
#   'great',
#   '.',
#   'corn',
#   'empanadas',
#   'different',
#   'good',
#   '.',
#   'kielbasa',
#   'bland',
#   'dry',
#   '.',
#   'brussels',
#   'sprouts',
#   'good',
#   'need',
#   'boost',
#   'flavor',
#   '.',
#   'order',
#   'grilled',
#   'salad',
#   'tasted',
#   'burnt',
#   'gritty.wish',
#   'meal',
#   'hotter',
#   'temperature',
#   '.',
#   'beer',
#   'selection',
#   'fantastic',
#   'gave',
#   'taste',
#   'committed',
#   'glass',
#   '.',
#   'place',
#   'packed',
# ...
#   'happy',
#   'accommodate',
#   ',',
#   'needed',
#   'figure',
#   'scheduling',
#   'issues',
#   '.',
#   'left',
#   'husband',
#   'excited',
#   'finally',
#   'found',
#   'artist',
#   'work',
#   'coverup',
#   '.',
#   '\n\n',
#   'husband',
#   'emailed',
#   'artist',
#   'pictures',
#   'hear',
#   '4',
#   'days',
#   'emailed',
#   '.',
#   'email',
#   'short',
#   ',',
#   'artist',
#   'enthusiastic',
#   'getting',
#   'job',
#   '.',
#   'husband',
#   'found',
#   'schedule',
#   'emailed',
#   'heard',
#   '.',
#   'called',
#   'shop',
#   'left',
#   'message',
#   'guy',
#   'artist',
#   ',',
#   'received',
#   'phone',
#   '.',
#   'waited',
#   'days',
#   ',',
#   'called',
#   ',',
#   'response',
#   '.',
#   '\n\n',
#   'like',
#   'good',
#   'work',
#   'husband',
#   'knew',
#   'piece',
#   ',',
#   'question',
#   'professionalism',
#   'customer',
#   'service',
#   '?',
#   'want',
#   'money',
#   ',',
#   'plenty',
#   'shops',
#   'area',
#   'happy',
#   '.',
#   'customer',
#   'service',
#   'disappointing',
#   '.'],
#  ['great',
#   'local',
#   'spot',
#   '.',
#   ' ',
#   'stopped',
#   'check',
#   'bringing',
#   'family',
#   'girl',
#   'working',
#   'entire',
#   'restaurant',
#   'invited',
#   ',',
#   'saying',
#   'best',
#   'food',
#   '.',
#   ' ',
#   'kidding',
#   '.',
#   'burgers',
#   'outstanding',
#   '.',
#   ' ',
#   'onion',
#   'rings',
#   'hand',
#   'dipped',
#   'best',
#   '.',
#   ' ',
#   'beer',
#   'selection',
#   'far',
#   'better',
#   'expected',
#   '.',
#   'rays',
#   'great',
#   'time',
#   '!'],
#  ['worst',
#   'customer',
#   'service',
#   '.',
#   'hostess',
#   'rude',
#   'second',
#   'entered',
#   '.',
#   'waiter',
#   'extremely',
#   'impatient',
#   '.',
#   'ordered',
#   'mushroom',
#   'shrimp',
#   'appetizer',
#   'pretty',
#   'terrible',
#   '.',
#   'tried',
#   'talk',
#   'owner',
#   'rude',
#   'staff',
#   'started',
#   'screaming',
#   '.',
#   '.'],
#  ['harrah',
#   'like',
#   'casinos',
#   'vegas',
#   ',',
#   'roulette',
#   'player',
#   'thing',
#   ',',
#   'drinks',
#   'free',
#   'flowing',
#   ',',
#   'people',
#   'working',
#   'pleasant',
#   'fun',
#   'environment',
#   '.'],
#  ['awesome',
#   'spot',
#   '.',
#   'manager',
#   'great',
#   ',',
#   'nice',
#   'vibe',
#   '.',
#   'food',
#   'cheap',
#   'splitting',
#   'hookah',
#   'comes',
#   'cheap',
#   '.',
#   'highly',
#   'recommend',
#   '!'],
#  ['david',
#   'witchell',
#   'empire',
#   'continues',
#   'grow',
#   'newtown',
#   ',',
#   'pa',
#   '.',
#   'solitary',
#   'salon',
#   'state',
#   'street',
#   'expanded',
#   'boutiques',
#   'covering',
#   'variety',
#   'clothing',
#   'styles',
#   ',',
#   'home',
#   'decor',
#   'showcase',
#   'allegheny',
#   'art',
#   'supply',
#   'store',
#   '.',
#   'bright',
#   'shiny',
#   'resolutely',
#   'old',
#   'school',
#   'newtown',
#   'borough',
#   '.',
#   ' \n\n',
#   'like',
#   '!',
#   '\n\n',
#   'walking',
#   'surprisingly',
#   'large',
#   'space',
#   'things',
#   'knew',
#   'find',
#   'attractive',
#   ',',
#   'reminded',
#   'recent',
#   'visit',
#   'southern',
#   'california',
#   '-',
#   'san',
#   'diego',
#   ',',
#   'la',
#   'jolla',
#   ',',
#   'laguna',
#   'beach',
#   'long',
#   'beach',
#   '.',
#   'beautiful',
#   'upscale',
#   'left',
#   'coast',
#   'culture',
#   'centers',
#   'shops',
#   'avenue',
#   'corner',
#   '.',
#   'provide',
#   'texture',
#   'ocean',
#   'view',
#   'mellow',
#   'yellow',
#   'lifestyle',
#   '.',
#   '(',
#   'yes',
#   '.',
#   'tchotchkes',
#   'found',
#   'new',
#   'hope',
#   'similar',
#   'venues',
#   ',',
#   'distance',
#   'new',
#   'town',
#   'hope',
#   'great',
#   'cal',
#   ')',
#   '.',
#   '\n\n',
#   'gala',
#   'kellie',
#   'cool',
#   ',',
#   'leaving',
#   'explore',
#   'knickknacks',
#   'crannies',
#   'light',
#   'direction',
#   'inquiry',
#   '.',
#   'picked',
#   'things',
#   '(',
#   'oversized',
#   'mugs',
#   'snowglobe',
#   'buddha',
#   ')',
#   ',',
#   'totally',
#   'need',
#   ',',
#   'enjoyed',
#   'impulse',
#   'purchasing',
#   '.',
#   ' \n\n',
#   'cheaper',
#   'return',
#   'flight',
#   'orange',
#   'county',
#   ',',
#   'whimsy',
#   'shop',
#   '.'],
#  ['typically',
#   'despise',
#   'chain',
#   'restaurants',
#   '.',
#   'especially',
#   'cattle',
#   'ones',
#   'owned',
#   'darden',
#   '(',
#   'parent',
#   'company',
#   'seasons',
#   '52',
#   ')',
#   'like',
#   'olive',
#   'garden',
#   ',',
#   'longhorn',
#   ',',
#   'bahama',
#   'breeze',
#   '.',
#   'time',
#   'went',
#   'seasons',
#   '52',
#   ',',
#   'super',
#   'impressed',
#   '.',
#   'commented',
#   'chain',
#   'restaurant',
#   'right',
#   '.',
#   'boy',
#   'wrong',
#   '.',
#   'visit',
#   '-',
#   'nightmare',
#   '.',
#   'matter',
#   'time',
#   'reservation',
#   '(',
#   'far',
#   'advance',
#   'reservation',
#   ')',
#   'm',
#   'kept',
#   'waiting',
#   '35min-',
#   '90',
#   'min',
#   'past',
#   'reservation',
#   'time',
#   'seated',
#   '.',
#   '\n\n',
#   'night',
#   'went',
#   'new',
#   'years',
#   'eve',
#   '.',
#   'booked',
#   'reservation',
#   'directly',
#   'restaurant',
#   'conclusion',
#   'visit',
#   'november',
#   '.',
#   'desk',
#   'said',
#   'little',
#   '.',
#   'turns',
#   'meant',
#   '50',
#   'minutes',
#   '.',
#   'complained',
#   ',',
#   'girl',
#   'said',
#   'told',
#   'little',
#   'management',
#   '.',
#   'spoke',
#   'manager',
#   ',',
#   'blamed',
#   'opentable',
#   '.',
#   'research',
#   ',',
#   'discovered',
#   'restaurants',
#   'use',
#   'opentable',
#   'typically',
#   '20',
#   '%',
#   '-',
#   'rate',
#   '.',
#   'counter',
#   ',',
#   'seasons',
#   '52',
#   'obviously',
#   'overbooks',
#   'reservations',
#   '20',
#   '%',
#   '.',
#   ' ',
#   'problem',
#   'shows',
#   '(',
#   'time',
#   ')',
#   '.',
#   'left',
#   'waiting',
#   'severely',
#   'overcrowded',
#   'restaurant',
#   'nt',
#   'squeeze',
#   'bar',
#   ',',
#   'let',
#   'seat',
#   'bar',
#   '.',
#   'woman',
#   'spoke',
#   'waiting',
#   'nearly',
#   'hours',
#   'called',
#   '.',
#   '\n\n',
#   'dealt',
#   'crap',
#   'visits',
#   ',',
#   'screw',
#   'new',
#   'years',
#   'eve',
#   ',',
#   'late',
#   ',',
#   'unacceptable',
#   '.',
#   'especially',
#   'confirm',
#   'reservation',
#   'twice',
#   '(',
#   'week',
#   'night',
#   ')',
#   '.',
#   '\n\n\n',
#   'best',
#   'way',
#   'restaurants',
#   'use',
#   'shady',
#   'reservation',
#   'tactics',
#   'expense',
#   'guests',
#   ',',
#   'stop',
#   'altogether',
#   '.',
#   'want',
#   'learn',
#   'lesson',
#   '?',
#   'restaurant',
#   '.',
#   'restaurant',
#   'business',
#   'better',
#   'darden',
#   'opentable',
#   'went',
#   'business',
#   '.'],
#  ['place',
#   'right',
#   'amazing',
#   '!',
#   '!',
#   'ordered',
#   'atleast',
#   '4',
#   'things',
#   'delicious',
#   '!',
#   '!',
#   'salad',
#   ',',
#   'soft',
#   'crunchy',
#   'sushi',
#   'glazed',
#   'dipped',
#   'chicken',
#   'shrimp',
#   '.',
#   'reasonably',
#   'priced',
#   ',',
#   'service',
#   'fast',
#   'efficent',
#   'friday',
#   'night',
#   '.',
#   'loved',
#   'tasted',
#   'went',
#   'home',
#   '\n',
#   'leftovers',
#   'ultimately',
#   'want',
#   '.',
#   'worth',
#   '5',
#   'star',
#   'review',
#   '!',
#   '!'],
#  ['takeout',
#   'night',
#   'delicious',
#   '.',
#   ' ',
#   'fresh',
#   'flavorful',
#   ',',
#   'perfectly',
#   'cooked',
#   '.',
#   ' ',
#   'definitely',
#   'returning',
#   '.'],
#  ['came',
#   '6:30',
#   'pm',
#   ',',
#   '30',
#   'minutes',
#   'closing',
#   '.',
#   'needed',
#   'quick',
#   'check',
#   'engine',
#   'smoking',
#   'earlier',
#   'drive',
#   'night',
#   '.',
#   'long',
#   'road',
#   'trip',
#   'needed',
#   'help',
#   '.',
#   'said',
#   ',',
#   'unsympathetic',
#   'way',
#   '.',
#   'busy',
#   'auto',
#   'mechanics',
#   'time',
#   'quick',
#   'look',
#   'bad',
#   '.',
#   'time',
#   ',',
#   'nicer',
#   '.',
#   'customer',
#   'service',
#   'important',
#   '.'],
#  ['second',
#   'meal',
#   'returning',
#   'soon',
#   '.',
#   'favorites',
#   'calamari',
#   ',',
#   'home',
#   'gnocchi',
#   ',',
#   'linguini',
#   'alla',
#   'pescatore',
#   '.',
#   'recommend',
#   'getting',
#   'gnocchi',
#   'blush',
#   'sauce',
#   'instead',
#   'rich',
#   'gorgonzola',
#   '.'],
#  ['wow',
#   '!',
#   'khao',
#   'soi',
#   'absolutely',
#   'incredible',
#   '.',
#   'fantastic',
#   'quality',
#   ',',
#   'perfectly',
#   'seasoned',
#   'entire',
#   'chicken',
#   'breast',
#   '.',
#   'tasted',
#   'wife',
#   'tofu',
#   'pad',
#   'thai',
#   '.',
#   'good',
#   '!',
#   'definitely',
#   'eat',
#   'time',
#   'santa',
#   'barbara',
#   '!'],
#  ['disappointing',
#   'vegetarian',
#   'fare',
#   '.',
#   'curry',
#   'tofu',
#   'soup',
#   'tasted',
#   'similar',
#   '.',
#   'summer',
#   'roles',
#   'plain',
#   '.',
#   ' ',
#   'wo',
#   'nt',
#   'return'],
#  ['yup',
#   '...',
#   'rude',
#   'lady',
#   'nice',
#   '.',
#   'lady',
#   'told',
#   'order',
#   'specialty',
#   'low',
#   'allergen',
#   'cat',
#   'food',
#   'needed',
#   '.',
#   'stopped',
#   'couple',
#   'months',
#   'later',
#   'second',
#   'lady',
#   'told',
#   'actually',
#   'special',
#   'order',
#   '.',
#   'hm',
#   '.',
#   ',',
#   'turns',
#   'carry',
#   'brand',
#   'use',
#   '(',
#   'natural',
#   'balance',
#   ')',
#   'non',
#   '-',
#   'issue',
#   '.',
#   '\n\n',
#   'good',
#   'place',
#   'shop',
#   'need',
#   'food',
#   'pet',
#   'special',
#   'diet',
#   '.',
#   'aisles',
#   'tiny',
#   'claustrophobic',
#   ',',
#   'small',
#   'shop',
#   'wide',
#   'selection',
#   '.'],
#  ['big',
#   'fix',
#   'worth',
#   '!',
#   'came',
#   'scoping',
#   'instagram',
#   'disappointed',
#   '.',
#   'enormous',
#   'bloody',
#   'mary',
#   'everyones',
#   'favorite',
#   ',',
#   'food',
#   'good',
#   '.'],
#  ['time',
#   'ate',
#   'gelati',
#   'rita',
#   'floored',
#   '.',
#   'thick',
#   'buttery',
#   'ice',
#   'cream',
#   'called',
#   'custard',
#   '?',
#   ',',
#   'mixed',
#   'tuti',
#   'fruity',
#   'water',
#   'ice',
#   ',',
#   'summer',
#   'philadelphia',
#   'begun',
#   '!',
#   'sleep',
#   'sweedish',
#   'fish',
#   'flavor',
#   '.',
#   'turn',
#   'mouth',
#   'red',
#   'good',
#   ':)',
#   'good',
#   'combos',
#   '=',
#   'mango+cherry',
#   'cherry',
#   '+',
#   '...',
#   'rita',
#   ',',
#   'bring',
#   'delish',
#   '"',
#   'whud',
#   '-',
#   'der',
#   '"',
#   'ice',
#   'california',
#   '.',
#   'sunny',
#   'year',
#   'round',
#   'woman',
#   '!'],
#  ['anxiety',
#   'attack',
#   '!',
#   '!',
#   '!',
#   'went',
#   'saturday',
#   'night',
#   '.',
#   'people',
#   'wo',
#   'find',
#   'place',
#   'sit',
#   '.',
#   'chaotic',
#   '!',
#   '!',
#   '!',
#   'pizza',
#   'fair',
#   ',',
#   'oddly',
#   'sweet',
#   ',',
#   'got',
#   'san',
#   'gennaro',
#   ',',
#   'want',
#   'standard',
#   'cheese',
#   'ask',
#   'extra',
#   'cheese',
#   '.',
#   'cannoli',
#   'maker',
#   'slow',
#   'making',
#   'order',
#   'receipt',
#   '...',
#   'unorganized'],
#  ['*',
#   '*',
#   '*',
#   '*',
#   'atrocious',
#   ',',
#   'cunning',
#   ',',
#   'deplorable',
#   'company',
#   '*',
#   '*',
#   '*',
#   '*',
#   '\n\n',
#   'needed',
#   'sf',
#   'bay',
#   'area',
#   ',',
#   'washington',
#   ',',
#   'dc',
#   'contacted',
#   'broker',
#   'assigned',
#   'company',
#   ',',
#   'little',
#   'know',
#   'thrown',
#   'complete',
#   ',',
#   'sheer',
#   'utter',
#   'nightmare',
#   '.',
#   'august',
#   '14th',
#   'driver',
#   'came',
#   'pick',
#   'car',
#   'signed',
#   'contract',
#   'stated',
#   'car',
#   'arrive',
#   'right',
#   'outside',
#   'dc',
#   'alexandria',
#   ',',
#   'va',
#   '5',
#   'days',
#   '.',
#   'flew',
#   'dc',
#   'days',
#   'later',
#   'contact',
#   '6',
#   'days',
#   'picked',
#   'car',
#   'busy',
#   'looking',
#   'apartments',
#   '.',
#   'contact',
#   'ask',
#   'car',
#   '8/20',
#   'answered',
#   '.',
#   'serval',
#   'hours',
#   'business',
#   'hours',
#   'called',
#   'called',
#   'answered',
#   '.',
#   ',',
#   'finally',
#   'man',
#   'answered',
#   'incredibly',
#   'rude',
#   'arrogant',
#   '.',
#   'said',
#   'car',
#   'tomorrow',
#   'afternoon',
#   '.',
#   'tomorrow',
#   'afternoon',
#   'came',
#   'called',
#   'company',
#   'said',
#   'evening',
#   '.',
#   'evening',
#   'came',
#   'sign',
#   'called',
#   'said',
#   'hours',
#   '.',
#   'hours',
#   'turned',
#   'day',
#   'come',
#   'day',
#   '.',
#   'dragged',
#   '8/24',
#   '!',
#   'worried',
#   'took',
#   'car',
#   'ran',
#   'called',
#   'dc',
#   'police',
#   'station',
#   'asked',
#   '.',
#   'police',
#   'gave',
#   'feedback',
#   'hung',
#   'driver',
#   'texted',
#   'address',
#   'half',
#   'hour',
#   'away',
#   'potomac',
#   ',',
#   'maryland',
#   'half',
#   'distance',
#   'alexandria',
#   '.',
#   "uber'ed",
#   'address',
#   'lo',
#   'behold',
#   '!',
#   '!',
#   '!',
#   '!',
#   'point',
#   'getting',
#   'angry',
#   'company',
#   'pick',
#   'calls',
#   ',',
#   'driver',
#   'pick',
#   'calls',
#   ',',
#   'delayed',
#   'car',
#   'arrival',
#   'dc',
#   '5',
#   'days',
#   'address',
#   'told',
#   '!',
#   '!',
#   'called',
#   'thank',
#   'goodness',
#   'answered',
#   'extreme',
#   'difficulty',
#   'telling',
#   '.',
#   'passerby',
#   'tell',
#   'phone',
#   '.',
#   'point',
#   'uber',
#   'driver',
#   'dropped',
#   'walk',
#   '20',
#   'mins',
#   'street',
#   'swelthering',
#   'august',
#   'heat',
#   '!',
#   '!',
#   '!',
#   'horrific',
#   'nightmare',
#   'finally',
#   'retrieved',
#   'car',
#   '!',
#   '!',
#   'surprised',
#   'damaged',
#   'honest',
#   '!',
#   '!',
#   '\n',
#   'company',
#   'horrendous',
#   'experience',
#   'customer',
#   '.',
#   'staff',
#   'negligent',
#   ',',
#   'rude',
#   ',',
#   'patronizing',
#   ',',
#   'unreliable',
#   'untrustworthy',
#   '!',
#   '!',
#   'mistake',
#   'google',
#   '/',
#   'research',
#   'company',
#   'services',
#   'rushed',
#   'dc',
#   '.'],
#  ['best',
#   'bar',
#   '-',
#   '-',
#   "que'd",
#   'oysters',
#   'world',
#   '!',
#   'casual',
#   ',',
#   'fancy',
#   ',',
#   'great',
#   'food',
#   '!'],
#  ['searched',
#   'local',
#   'online',
#   'nurseries',
#   'beat',
#   'guys',
#   '.',
#   'huge',
#   'selection',
#   'plants',
#   ',',
#   'soils',
#   ',',
#   'pots',
#   ',',
#   'etc',
#   'wonderful',
#   'customer',
#   'service',
#   '.',
#   'gave',
#   'finding',
#   'variegated',
#   'monstera',
#   'deliciosa',
#   ',',
#   'came',
#   '2',
#   '-',
#   '3',
#   'weeks',
#   'waitlist',
#   ',',
#   'happier',
#   '.',
#   ',',
#   'knew',
#   'plant',
#   'selling',
#   'approximately',
#   '$',
#   '100',
#   '-',
#   '150',
#   'ebay',
#   ',',
#   'sold',
#   'reasonable',
#   'price',
#   '.',
#   'tremendously',
#   'impressed',
#   'ethics',
#   ',',
#   'rest',
#   'easy',
#   'knowing',
#   'paid',
#   '1/4',
#   'paying',
#   'plants',
#   '.',
#   '-',
#   'plant',
#   'needs',
#   ',',
#   '.',
#   'thank',
#   ',',
#   'guys',
#   '!',
#   'express',
#   'appreciative',
#   'business',
#   'exists',
#   'tell',
#   'friends',
#   'family',
#   '.'],
#  ['highly',
#   'professional',
#   'services',
#   '.',
#   'beautiful',
#   'office',
#   '.',
#   'pleased',
#   'results',
#   '.',
#   'honest',
#   'recommended',
#   'thought',
#   'best',
#   '.',
#   'work',
#   'subtle',
#   'people',
#   ',',
#   'including',
#   'husband',
#   ',',
#   'thought',
#   '"',
#   'rested',
#   '"',
#   'looking',
#   'versus',
#   '"',
#   'wow',
#   ',',
#   '?',
#   '?',
#   '"',
#   'reaction',
#   '.'],
#  ['friendly',
#   ',',
#   'prompt',
#   'service',
#   'excellent',
#   '.',
#   '\n',
#   'simply',
#   'ask',
#   'small',
#   'biz',
#   '.',
#   '\n\n',
#   'matcha',
#   'whisked',
#   'spot',
#   'pleasant',
#   '.'],
#  ['love',
#   'restaurant',
#   '!',
#   'great',
#   'fish',
#   'pasta',
#   '.',
#   'service',
#   'friendly',
#   'professional',
#   '.',
#   'time',
#   'glassboro',
#   'area',
#   ',',
#   'visit',
#   'delicious',
#   'meal',
#   '.',
#   'good',
#   '!'],
#  ['tried',
#   'place',
#   'time',
#   '.',
#   'loved',
#   '!',
#   '!',
#   '!',
#   'got',
#   'gel',
#   'manicure',
#   'came',
#   'fabulous',
#   '!',
#   'new',
#   'spot',
#   '!'],
#  ['fell',
#   'love',
#   'place',
#   'minute',
#   'walked',
#   '.',
#   'got',
#   'better',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'beautiful',
#   'furniture',
#   '!',
#   '!',
#   '!',
#   'choose',
#   ',',
#   'farm',
#   'tables',
#   'dinning',
#   'room',
#   ',',
#   'living',
#   'room',
#   ',',
#   'light',
#   'fixtures',
#   '....',
#   'etc.the',
#   'store',
#   'goes',
#   '.',
#   'service',
#   'best',
#   '.',
#   'helpful',
#   ',',
#   'great',
#   'information',
#   'suggestions',
#   '.',
#   'need',
#   'furnish',
#   '2/2',
#   'condo',
#   'think',
#   'purchased',
#   'treehouse',
#   'galleries',
#   '!'],
#  ['enjoyed',
#   'holiday',
#   'menu',
#   'feast',
#   'seven',
#   'fishes',
#   '.',
#   ' ',
#   'food',
#   'phenomenal',
#   'server',
#   '.'],
#  ['guys',
#   'suck',
#   '.',
#   'takes',
#   '2',
#   'weeks',
#   'estimate',
#   ',',
#   'find',
#   'calling',
#   '3',
#   'times',
#   '.',
#   '2',
#   'weeks',
#   'fix!!!',
#   '......',
#   '4',
#   'weeks',
#   'total',
#   'replace',
#   'damned',
#   'crystal',
#   '?',
#   '?',
#   ',',
#   '-',
#   'called',
#   'manager',
#   'gives',
#   'attitude',
#   ',',
#   '.',
#   '\n\n',
#   'bullshit'],
#  ['better',
#   'markets',
#   'area',
#   ',',
#   'plenty',
#   'options',
#   'inexpensive',
#   'store',
#   'brands',
#   'premium',
#   'items',
#   '.',
#   'produce',
#   'good',
#   'reasonably',
#   'priced',
#   '.',
#   'organic',
#   'milk',
#   ',',
#   'reasonably',
#   'priced',
#   '.',
#   'appreciate',
#   'fact',
#   'stock',
#   'vernors',
#   ',',
#   'usually',
#   'find',
#   'deal',
#   'craft',
#   'beer',
#   'and/or',
#   'hard',
#   'cider',
#   ',',
#   'shasta',
#   'diet',
#   'soda',
#   'uses',
#   'splenda',
#   '.',
#   'like',
#   'fact',
#   'favorites',
#   'olive',
#   'bar',
#   'soaked',
#   'oil',
#   ',',
#   'increases',
#   'weight',
#   ',',
#   'flavor',
#   '.'],
#  ['nice',
#   'location',
#   '..',
#   'food',
#   'horrible',
#   '..',
#   'real',
#   'chief',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'potential',
#   '..',
#   'food',
#   'horrible'],
#  ...]

# %%
# we now copy the methodology used in the reference book
w2v_array = []
for text in w2v_inputs:
    text_array = np.zeros(300)
    len_count = 0
    for token in text:
        if token in w2v:
            text_array += w2v[token]
            len_count += 1
    if len_count != 0:
        text_array /= len_count
    w2v_array.append(text_array)

# %%
# prepare for train
X_train, X_test, y_train, y_test = train_test_split(np.array(w2v_array), np.array(review_group), test_size = 0.25, random_state=0)

# using KNNs for classification
knn = KNeighborsClassifier(n_neighbors=20).fit(X_train, y_train)
print("KNN test score:", knn.score(X_test, y_test))
print("KNN train score:", knn.score(X_train, y_train))

# using SVMs for classification
svm = SVC().fit(X_train, y_train)
print("SVM test score:", svm.score(X_test, y_test))
print("SVM train score:", svm.score(X_train, y_train))

# using random forests for classification
rfc = RandomForestClassifier(max_depth=6, random_state=0).fit(X_train, y_train)
print("RF test score:", rfc.score(X_test, y_test))
print("RF train score:", rfc.score(X_train, y_train))

# using logistic regression for classification
lrc = LogisticRegression(random_state=0).fit(X_train, y_train)
print("LR test score:", lrc.score(X_test, y_test))
print("LR train score:", lrc.score(X_train, y_train))

# using logistic regression for classification
nbc = MultinomialNB().fit(X_train, y_train)
print("NB test score:", nbc.score(X_test, y_test))
print("NB train score:", nbc.score(X_train, y_train))
# Out:
# KNN test score: 0.5584
# KNN train score: 0.6151333333333333
# SVM test score: 0.6086
# SVM train score: 0.6942666666666667
# RF test score: 0.5642
# RF train score: 0.7124
# LR test score: 0.606
# LR train score: 0.6183333333333333
# /Users/fernandoassad/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-0b23f9d2b885> in <module>
#      23
#      24 # using logistic regression for classification
# ---> 25 nbc = MultinomialNB().fit(X_train, y_train)
#      26 print("NB test score:", nbc.score(X_test, y_test))
#      27 print("NB train score:", nbc.score(X_train, y_train))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     636
#     637         self._init_counters(n_effective_classes, n_features)
# --> 638         self._count(X, Y)
#     639         alpha = self._check_alpha()
#     640         self._update_feature_log_prob(alpha)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     769     def _count(self, X, Y):
#     770         """Count and smooth feature occurrences."""
# --> 771         check_non_negative(X, "MultinomialNB (input X)")
#     772         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     773         self.class_count_ += Y.sum(axis=0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1066
#    1067     if X_min < 0:
# -> 1068         raise ValueError("Negative values in data passed to %s" % whom)
#    1069
#    1070
#
# ValueError: Negative values in data passed to MultinomialNB (input X)
